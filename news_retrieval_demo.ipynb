# %% [markdown]
# # News Retrieval Pipeline for Forecasting
#
# This notebook demonstrates the news retrieval pipeline that uses LLMs to:
# 1. **Generate search keywords** optimized for Google News
# 2. **Retrieve relevant news** articles using the generated keywords
# 3. **Rate the relevance** of each news article (1-5 scale)
# 4. **Synthesize all relevant news** into a single cohesive summary

# %% [markdown]
# ## Select a Question

# %%
question = "Will Apple release a new iPhone model before June 2024?"
background = "Apple typically releases new iPhone models in September each year."
question_date = "2024-03-01"

# %% [markdown]
# ## Initialize and Run Pipeline
#
# Set parameters for the news retrieval pipeline.

# %%
# Pipeline configuration
pipeline_config = {
    'num_keywords': 4,            # Number of search keywords to generate
    'news_per_keyword': 2,        # News articles to retrieve per keyword
    'min_news_rating': 3,         # Minimum relevance rating (1-5) to keep articles
    'news_period_days': 90,       # How many days back to search for news
    'question_gen_temp': 0.7,     # Temperature for keyword generation
    'news_rating_temp': 0.3,      # Temperature for news rating
    'summarization_temp': 0.5,    # Temperature for summarization
    'max_tokens': 1000            # Max tokens for LLM responses
}

# %% [markdown]
# ## Initialize and Run Pipeline

# %%
from forecast_kag.news_retrieval import NewsRetrievalPipeline

pipeline = NewsRetrievalPipeline(
     keyword_model="qwen80",      # For keyword generation
     rating_model="qwen80",         # For rating articles
     summarization_model="oss120",  # For summarization
     **pipeline_config
 )

# Run pipeline
print("="*80)
results = pipeline.run(
    question=question,
    background=background,
    question_date=question_date
)
print("="*80)
# Out:
# 11/16/2025 12:31:08 PM - ================================================================================
# 11/16/2025 12:31:08 PM - NEWS RETRIEVAL PIPELINE
# 11/16/2025 12:31:08 PM - ================================================================================
# 11/16/2025 12:31:08 PM - Question: Will Apple release a new iPhone model before June 2024?
# 11/16/2025 12:31:08 PM - Date Range: 90 days
# 11/16/2025 12:31:08 PM - ================================================================================
# 11/16/2025 12:31:08 PM - News search cutoff date: 2024-03-01
# 11/16/2025 12:31:08 PM - Searching news from 2023-12-02 to 2024-03-01
# 11/16/2025 12:31:08 PM - [Agent 1: Keyword Generation] Generating 4 search keywords...
# 11/16/2025 12:31:08 PM - Calling LLM for Keyword Generation...
# ================================================================================
# 11/16/2025 12:31:10 PM - Keyword Generation completed
# 11/16/2025 12:31:10 PM - Generated 4 search keywords
# 11/16/2025 12:31:10 PM -   1. Apple iPhone early release rumors 2024
# 11/16/2025 12:31:10 PM -   2. iPhone 16 production schedule leak
# 11/16/2025 12:31:10 PM -   3. Apple spring product launch event 2024
# 11/16/2025 12:31:10 PM -   4. iPhone 2024 prototype testing reports
# 11/16/2025 12:31:10 PM -
# [Agent 2: News Retrieval] Preparing search queries...
# 11/16/2025 12:31:10 PM - Original question: 'Will Apple release a new iPhone model before June 2024?...'
# 11/16/2025 12:31:10 PM - Total search queries: 5 (1 original + 4 keywords)
# 11/16/2025 12:31:10 PM - Executing 5 news searches...
# 11/16/2025 12:31:10 PM - Query 1/5 [ORIGINAL]: 'Will Apple release a new iPhone model before June 2024?...'
# 11/16/2025 12:31:15 PM - Found 2 articles
# 11/16/2025 12:31:15 PM - Query 2/5 [KEYWORD 1]: 'Apple iPhone early release rumors 2024...'
# 11/16/2025 12:31:18 PM - Found 2 articles
# 11/16/2025 12:31:18 PM - Query 3/5 [KEYWORD 2]: 'iPhone 16 production schedule leak...'
# 11/16/2025 12:31:21 PM - Found 2 articles
# 11/16/2025 12:31:21 PM - Query 4/5 [KEYWORD 3]: 'Apple spring product launch event 2024...'
# 11/16/2025 12:31:23 PM - Excluded FUTURE article: 'Get ready for new MacBooks and iPads at Apple Marc'
# 11/16/2025 12:31:23 PM - Found 1 articles
# 11/16/2025 12:31:23 PM - Query 5/5 [KEYWORD 4]: 'iPhone 2024 prototype testing reports...'
# 11/16/2025 12:31:27 PM - Found 2 articles
# 11/16/2025 12:31:27 PM - Retrieved 9 total articles from 5 queries
# 11/16/2025 12:31:27 PM -
# [Agent 3: Rating] Rating 9 articles...
# 11/16/2025 12:31:27 PM -
# Article 1/9: 'Apple TV+ unveils a sneak peek at star-studded lineup of new...'
# 11/16/2025 12:31:27 PM - Rating...
# 11/16/2025 12:31:28 PM - Rating: 1/5
# 11/16/2025 12:31:28 PM - Filtered out (rating < 3)
# 11/16/2025 12:31:28 PM -
# Article 2/9: 'How the Apple iPhone became one of the best-selling products...'
# 11/16/2025 12:31:28 PM - Rating...
# 11/16/2025 12:31:29 PM - Rating: 2/5
# 11/16/2025 12:31:29 PM - Filtered out (rating < 3)
# 11/16/2025 12:31:29 PM -
# Article 3/9: 'Apple Vision Pro available in the U.S. on February 2 - Apple...'
# 11/16/2025 12:31:29 PM - Rating...
# 11/16/2025 12:31:30 PM - Rating: 2/5
# 11/16/2025 12:31:30 PM - Filtered out (rating < 3)
# 11/16/2025 12:31:30 PM -
# Article 4/9: 'iPhone 16 in 2024 — here's everything Apple could announce t...'
# 11/16/2025 12:31:30 PM - Rating...
# 11/16/2025 12:31:32 PM - Rating: 4/5
# 11/16/2025 12:31:32 PM -
# Article 5/9: 'iPhone 16 leak reveals Apple may have ditched bold design ch...'
# 11/16/2025 12:31:32 PM - Rating...
# 11/16/2025 12:31:33 PM - Rating: 4/5
# 11/16/2025 12:31:33 PM -
# Article 6/9: 'Leaked iPhone 16 design is giving me major 2017 vibes - Crea...'
# 11/16/2025 12:31:33 PM - Rating...
# 11/16/2025 12:31:35 PM - Rating: 4/5
# 11/16/2025 12:31:35 PM -
# Article 7/9: 'Apple March event: Everything we know so far - 9to5Mac...'
# 11/16/2025 12:31:35 PM - Rating...
# 11/16/2025 12:31:36 PM - Rating: 4/5
# 11/16/2025 12:31:36 PM -
# Article 8/9: 'Apple developing prototypes for a foldable clamshell iPhone:...'
# 11/16/2025 12:31:36 PM - Rating...
# 11/16/2025 12:31:37 PM - Rating: 2/5
# 11/16/2025 12:31:37 PM - Filtered out (rating < 3)
# 11/16/2025 12:31:37 PM -
# Article 9/9: 'iPhone Flip: what we know about Apple’s first foldable phone...'
# 11/16/2025 12:31:37 PM - Rating...
# 11/16/2025 12:31:39 PM - Rating: 2/5
# 11/16/2025 12:31:39 PM - Filtered out (rating < 3)
# 11/16/2025 12:31:39 PM -
# 4 articles meet threshold (rating >= 3)
# 11/16/2025 12:31:39 PM -
# [Agent 4: Summarization] Synthesizing 4 articles into cohesive summary...
# 11/16/2025 12:31:39 PM - Calling LLM for Article Synthesis...
# 11/16/2025 12:31:42 PM - Article Synthesis completed
# 11/16/2025 12:31:42 PM - Synthesis completed (1084 characters)
# 11/16/2025 12:31:42 PM -
# ================================================================================
# 11/16/2025 12:31:42 PM - PIPELINE COMPLETED SUCCESSFULLY
# 11/16/2025 12:31:42 PM - ================================================================================
# ================================================================================

# %% [markdown]
# ### Pipeline Statistics

# %%
print("\n" + "="*80)
print("PIPELINE STATISTICS")
print("="*80)
for key, value in results['stats'].items():
    print(f"{key}: {value}")
print("="*80)
# Out:
# ================================================================================
# PIPELINE STATISTICS
# ================================================================================
# num_search_keywords: 4
# total_articles_retrieved: 9
# total_articles_rated: 9
# relevant_articles: 4
# min_rating_threshold: 3
# ================================================================================

# %% [markdown]
# ### Generated Search Keywords

# %%
print("\n" + "="*80)
print("GENERATED SEARCH KEYWORDS")
print("="*80)
for i, kw in enumerate(results['search_keywords'], 1):
    print(f"{i}. {kw}")
print("="*80)
# Out:
# ================================================================================
# GENERATED SEARCH KEYWORDS
# ================================================================================
# 1. Apple iPhone early release rumors 2024
# 2. iPhone 16 production schedule leak
# 3. Apple spring product launch event 2024
# 4. iPhone 2024 prototype testing reports
# ================================================================================

# %% [markdown]
# ### All Retrieved News Articles (with Ratings)
#
# All articles retrieved and rated by the pipeline, sorted by relevance rating.

# %%
print("\n" + "="*80)
print(f"ALL RETRIEVED NEWS ARTICLES ({len(results['all_rated_news'])} total)")
print("="*80)

if results['all_rated_news']:
    for i, article in enumerate(results['all_rated_news'], 1):
        print(f"\n{i}. [RATING: {article['relevance_rating']}/5]")
        print(f"   Title: {article.get('title', 'N/A')}")
        print(f"   Publisher: {article.get('publisher', {}).get('title', 'N/A') if isinstance(article.get('publisher'), dict) else 'N/A'}")
        print(f"   Date: {article.get('published date', 'N/A')}")
        print(f"   URL: {article.get('url', 'N/A')}")
        print(f"   Description: {article.get('description', 'N/A')[:200]}...")
        print(f"   Search Query: {article.get('search_query', 'N/A')[:60]}...")
else:
    print("No articles retrieved.")
print("\n" + "="*80)
# Out:
# ================================================================================
# ALL RETRIEVED NEWS ARTICLES (9 total)
# ================================================================================
#
# 1. [RATING: 4/5]
#    Title: iPhone 16 in 2024 — here's everything Apple could announce this year - Tom's Guide
#    Publisher: Tom's Guide
#    Date: Sun, 31 Dec 2023 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMiWEFVX3lxTE5kbVNNWko2eDhXdkh3aWlieXhLX29BZUxiaHhsUFF3ZF9OSFNkVzVsVVNpdFhlZHF4UGVnWGMxWUhXdDItWDgwdkhfVUtGRE5UOHFmTTRuRXY?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: iPhone 16 in 2024 — here's everything Apple could announce this year  Tom's Guide...
#    Search Query: Apple iPhone early release rumors 2024...
#
# 2. [RATING: 4/5]
#    Title: iPhone 16 leak reveals Apple may have ditched bold design change for more of the same - iMore
#    Publisher: iMore
#    Date: Wed, 13 Dec 2023 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: iPhone 16 leak reveals Apple may have ditched bold design change for more of the same  iMore...
#    Search Query: iPhone 16 production schedule leak...
#
# 3. [RATING: 4/5]
#    Title: Leaked iPhone 16 design is giving me major 2017 vibes - Creative Bloq
#    Publisher: Creative Bloq
#    Date: Wed, 07 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMiX0FVX3lxTE9aUURaUElVWGtyWFZoaE14MEpYdXphN2w4QTlZSmVMdE13REY0dVNaQjJaaGtjTnR1dUxJUW1zU185Q21iQm5iMjgwSmZud0h2V2t3N0FXdThLeEZvZkRr?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Leaked iPhone 16 design is giving me major 2017 vibes  Creative Bloq...
#    Search Query: iPhone 16 production schedule leak...
#
# 4. [RATING: 4/5]
#    Title: Apple March event: Everything we know so far - 9to5Mac
#    Publisher: 9to5Mac
#    Date: Wed, 14 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMigAFBVV95cUxNdF9wNzA5TWd1eHlyYlJ6NUZiYU95YUhRcmZwTG9hZDR3OUoxWWJqUHlYQ01oeEJuQmlmV2JSWGVYbl9GaVlWV01aYlE5djdNSkhLRkpuYmxLNjNPRGEtcVQ0Sy1taWQ0dmJSTWk2cXM4a05xUng4bnYtQTRSYUU5aQ?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple March event: Everything we know so far  9to5Mac...
#    Search Query: Apple spring product launch event 2024...
#
# 5. [RATING: 2/5]
#    Title: How the Apple iPhone became one of the best-selling products of all time - CNBC
#    Publisher: CNBC
#    Date: Sat, 27 Jan 2024 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: How the Apple iPhone became one of the best-selling products of all time  CNBC...
#    Search Query: Will Apple release a new iPhone model before June 2024?...
#
# 6. [RATING: 2/5]
#    Title: Apple Vision Pro available in the U.S. on February 2 - Apple
#    Publisher: Apple
#    Date: Mon, 08 Jan 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMilAFBVV95cUxNMDU0LUxSY1JqRU1va0JhTHZoMDNad1Y2OURHaC1yb0MtUnhJVFlKWVhCZDdiRjc1Z2Y3S3lDNW5LMEZZakhQM2g0a2EwWWVwcTJLWmpvVEw4Y0Jabks5UkxjV3pGNkM5TDk2SGRjY1dNUlFJNDd0dGNTNG5tVGFhMHg4MGdvX0pGbHVyMjdKc3UxeWZG?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple Vision Pro available in the U.S. on February 2  Apple...
#    Search Query: Apple iPhone early release rumors 2024...
#
# 7. [RATING: 2/5]
#    Title: Apple developing prototypes for a foldable clamshell iPhone: report - New York Post
#    Publisher: New York Post
#    Date: Wed, 07 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMinAFBVV95cUxPR3JabzRRd1ZCWVFDRzE3UHVVU0JGRjczd3JuRnVqS0xxT2NoTTBocmpuaUJla0VaRjdRbV9NZ0VzdDJyOXZHdDNrWVBQOURya3V5RjdtdE9SckttNFYxbXVFaTBYWmpIeHBKcGs5MWd1cm50TVhLSk1zRWJybnpSNWdBSlN1X1p0Q01XazNaMkU2QTQtem14bXF5NUk?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple developing prototypes for a foldable clamshell iPhone: report  New York Post...
#    Search Query: iPhone 2024 prototype testing reports...
#
# 8. [RATING: 2/5]
#    Title: iPhone Flip: what we know about Apple’s first foldable phone - Yahoo
#    Publisher: Yahoo
#    Date: Wed, 14 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMiekFVX3lxTE15SlNYMFVVcThwUU9CUm1jOEZXVmxFNnZhTTlYT0ZNTE5rTGVvZTZXYXgtZHZjell3ZHVhN050UGV0RktzZlNoWnhhOGZJWVRoZ2VyYm5QZWZZZThMTU92ZVFYNDczTmhaZ21RTUxQLV81RjdqS1NvQmtB?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: iPhone Flip: what we know about Apple’s first foldable phone  Yahoo...
#    Search Query: iPhone 2024 prototype testing reports...
#
# 9. [RATING: 1/5]
#    Title: Apple TV+ unveils a sneak peek at star-studded lineup of new and returning original series set to debut in 2024 - Apple
#    Publisher: Apple
#    Date: Mon, 05 Feb 2024 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple TV+ unveils a sneak peek at star-studded lineup of new and returning original series set to debut in 2024  Apple...
#    Search Query: Will Apple release a new iPhone model before June 2024?...
#
# ================================================================================

# %% [markdown]
# ### News Summary (Synthesized Analysis)
#
# This summary synthesizes all articles with rating >= minimum threshold into a single cohesive analysis. The summary identifies key factors affecting the forecasting question by combining insights from all relevant articles, eliminating redundant information, and focusing on verifiable facts without editorial opinions.

# %%
print("\n" + "="*80)
print(f"NEWS SUMMARY (Only articles with rating >= {pipeline_config['min_news_rating']})")
print("="*80)
print(f"\nRelevant articles: {len(results['relevant_news'])}/{len(results['all_rated_news'])}\n")
print(results['summary'])
print("\n" + "="*80)
# Out:
# ================================================================================
# NEWS SUMMARY (Only articles with rating >= 3)
# ================================================================================
#
# Relevant articles: 4/9
#
# Apple’s iPhone releases have historically been tied to a September‑time special event, and the articles note that the next iPhone launch is anticipated for September 2024. No Apple‑announced event before June 2024 is dedicated to a new iPhone; the confirmed early‑year events are a February 2024 launch of the Apple Vision Pro headset and the June 2024 Worldwide Developers Conference (WWDC), which focus on software and other product categories.
#
# The coverage details multiple design leaks for the upcoming iPhone 16, including changes to the camera layout, the addition of an Action button and a Capture button, and various button configurations. These leaks describe prototype renderings and speculation about the device’s appearance but do not provide an official release date or confirmation from Apple.
#
# Because Apple’s official schedule lists only a Vision Pro launch in February and WWDC in June, and because the next iPhone event is described as occurring in September, the factual record from the articles does not indicate any confirmed iPhone release before June 2024.
#
# ================================================================================
