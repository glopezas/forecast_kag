# %% [markdown]
# # News Retrieval Pipeline for Forecasting
#
# This notebook demonstrates the news retrieval pipeline that uses LLMs to:
# 1. **Generate search keywords** optimized for Google News
# 2. **Retrieve relevant news** articles using the generated keywords
# 3. **Rate the relevance** of each news article (1-5 scale)
# 4. **Synthesize all relevant news** into a single cohesive summary
#
# **Important**: Only news articles that meet the minimum relevance threshold are passed to the summarization agent. The summary synthesizes all relevant articles into a factual analysis of key factors affecting the forecasting question, without listing individual articles or adding editorial opinions.

# %% [markdown]
# ## Setup and Imports

# %%
import sys
import pandas as pd
from datasets import load_dataset
import warnings
warnings.filterwarnings('ignore')

from forecast_kag.news_retrieval import NewsRetrievalPipeline

# %% [markdown]
# ## Select a Question

# %%
question = "Will Apple release a new iPhone model before June 2024?"
background = "Apple typically releases new iPhone models in September each year."
question_date = "2024-03-01"

# %% [markdown]
# ## Configure Pipeline Parameters
#
# Set parameters for the news retrieval pipeline.

# %%
# Pipeline configuration
pipeline_config = {
    'num_questions': 5,           # Number of search keywords to generate
    'news_per_keyword': 2,        # News articles to retrieve per keyword
    'min_news_rating': 3,         # Minimum relevance rating (1-5) to keep articles
    'news_period_days': 90,       # How many days back to search for news
    'question_gen_temp': 0.7,     # Temperature for keyword generation
    'news_rating_temp': 0.3,      # Temperature for news rating
    'summarization_temp': 0.5,    # Temperature for summarization
    'max_tokens': 1000            # Max tokens for LLM responses
}

# %% [markdown]
# ## Initialize and Run Pipeline
#
# Create the pipeline and run it on the selected question.

# %%
pipeline = NewsRetrievalPipeline(
    model_shortname="llama70",
    **pipeline_config
)

results = pipeline.run(
    question=question,
    background=background,
    question_date=question_date
)
# Out:
# 11/16/2025 11:44:16 AM - ================================================================================
# 11/16/2025 11:44:16 AM - NEWS RETRIEVAL PIPELINE
# 11/16/2025 11:44:16 AM - ================================================================================
# 11/16/2025 11:44:16 AM - Question: Will Apple release a new iPhone model before June 2024?
# 11/16/2025 11:44:16 AM - Date Range: 90 days
# 11/16/2025 11:44:16 AM - ================================================================================
# 11/16/2025 11:44:16 AM - News search cutoff date: 2024-03-01
# 11/16/2025 11:44:16 AM - Searching news from 2023-12-02 to 2024-03-01
# 11/16/2025 11:44:16 AM - [Agent 1: Keyword Generation] Generating 5 search keywords...
# 11/16/2025 11:44:16 AM - Calling LLM for Keyword Generation...
# 11/16/2025 11:44:18 AM - Keyword Generation completed
# 11/16/2025 11:44:18 AM - Generated 5 search keywords
# 11/16/2025 11:44:18 AM -   1. Apple iPhone early release rumors 2024
# 11/16/2025 11:44:18 AM -   2. iPhone 16 production schedule leak
# 11/16/2025 11:44:18 AM -   3. Apple spring product launch event 2024
# 11/16/2025 11:44:18 AM -   4. iPhone new model prototype unveiling
# 11/16/2025 11:44:18 AM -   5. Apple deviates from September release tradition
# 11/16/2025 11:44:18 AM -
# [Agent 2: News Retrieval] Preparing search queries...
# 11/16/2025 11:44:18 AM - Original question: 'Will Apple release a new iPhone model before June 2024?...'
# 11/16/2025 11:44:18 AM - Total search queries: 6 (1 original + 5 keywords)
# 11/16/2025 11:44:18 AM - Executing 6 news searches...
# 11/16/2025 11:44:18 AM - Query 1/6 [ORIGINAL]: 'Will Apple release a new iPhone model before June 2024?...'
# 11/16/2025 11:44:20 AM - Found 2 articles
# 11/16/2025 11:44:20 AM - Query 2/6 [KEYWORD 1]: 'Apple iPhone early release rumors 2024...'
# 11/16/2025 11:44:24 AM - Found 2 articles
# 11/16/2025 11:44:24 AM - Query 3/6 [KEYWORD 2]: 'iPhone 16 production schedule leak...'
# 11/16/2025 11:44:27 AM - Found 2 articles
# 11/16/2025 11:44:27 AM - Query 4/6 [KEYWORD 3]: 'Apple spring product launch event 2024...'
# 11/16/2025 11:44:29 AM - Excluded FUTURE article: 'Get ready for new MacBooks and iPads at Apple Marc'
# 11/16/2025 11:44:29 AM - Found 1 articles
# 11/16/2025 11:44:29 AM - Query 5/6 [KEYWORD 4]: 'iPhone new model prototype unveiling...'
# 11/16/2025 11:44:31 AM - Found 2 articles
# 11/16/2025 11:44:31 AM - Query 6/6 [KEYWORD 5]: 'Apple deviates from September release tradition...'
# 11/16/2025 11:44:32 AM - Found 0 articles
# 11/16/2025 11:44:32 AM - Retrieved 9 total articles from 6 queries
# 11/16/2025 11:44:32 AM -
# [Agent 3: Rating] Rating 9 articles...
# 11/16/2025 11:44:32 AM -
# Article 1/9: 'Apple announces changes to iOS, Safari, and the App Store in...'
# 11/16/2025 11:44:32 AM - Rating...
# 11/16/2025 11:44:34 AM - Rating: 2/5
# 11/16/2025 11:44:34 AM - Filtered out (rating < 3)
# 11/16/2025 11:44:34 AM -
# Article 2/9: 'How the Apple iPhone became one of the best-selling products...'
# 11/16/2025 11:44:34 AM - Rating...
# 11/16/2025 11:44:36 AM - Rating: 2/5
# 11/16/2025 11:44:36 AM - Filtered out (rating < 3)
# 11/16/2025 11:44:36 AM -
# Article 3/9: 'Apple Vision Pro available in the U.S. on February 2 - Apple...'
# 11/16/2025 11:44:36 AM - Rating...
# 11/16/2025 11:44:38 AM - Rating: 2/5
# 11/16/2025 11:44:38 AM - Filtered out (rating < 3)
# 11/16/2025 11:44:38 AM -
# Article 4/9: 'iPhone 16 in 2024 — here's everything Apple could announce t...'
# 11/16/2025 11:44:38 AM - Rating...
# 11/16/2025 11:44:41 AM - Rating: 4/5
# 11/16/2025 11:44:41 AM -
# Article 5/9: 'iPhone 16 leak reveals Apple may have ditched bold design ch...'
# 11/16/2025 11:44:41 AM - Rating...
# 11/16/2025 11:44:44 AM - Rating: 2/5
# 11/16/2025 11:44:44 AM - Filtered out (rating < 3)
# 11/16/2025 11:44:44 AM -
# Article 6/9: 'Leaked iPhone 16 design is giving me major 2017 vibes - Crea...'
# 11/16/2025 11:44:44 AM - Rating...
# 11/16/2025 11:44:47 AM - Rating: 4/5
# 11/16/2025 11:44:47 AM -
# Article 7/9: 'Apple March event: Everything we know so far - 9to5Mac...'
# 11/16/2025 11:44:47 AM - Rating...
# 11/16/2025 11:44:50 AM - Rating: 4/5
# 11/16/2025 11:44:50 AM -
# Article 8/9: 'Early iPhone 16 Prototype Unveils Updated Design, Is It Trul...'
# 11/16/2025 11:44:50 AM - Rating...
# 11/16/2025 11:44:52 AM - Rating: 4/5
# 11/16/2025 11:44:52 AM -
# Article 9/9: 'Leaked iPhone 16 ‘prototypes’ point to possible return of ve...'
# 11/16/2025 11:44:52 AM - Rating...
# 11/16/2025 11:44:55 AM - Rating: 4/5
# 11/16/2025 11:44:55 AM -
# 5 articles meet threshold (rating >= 3)
# 11/16/2025 11:44:55 AM -
# [Agent 4: Summarization] Synthesizing 5 articles into cohesive summary...
# 11/16/2025 11:44:55 AM - Calling LLM for Article Synthesis...
# 11/16/2025 11:45:04 AM - Article Synthesis completed
# 11/16/2025 11:45:04 AM - Synthesis completed (1833 characters)
# 11/16/2025 11:45:04 AM -
# ================================================================================
# 11/16/2025 11:45:04 AM - PIPELINE COMPLETED SUCCESSFULLY
# 11/16/2025 11:45:04 AM - ================================================================================

# %% [markdown]
# ## Display Results

# %% [markdown]
# ### Pipeline Statistics

# %%
for key, value in results['stats'].items():
    print(f"{key}: {value}")
# Out:
# num_search_keywords: 5
# total_articles_retrieved: 9
# total_articles_rated: 9
# relevant_articles: 5
# min_rating_threshold: 3

# %% [markdown]
# ### Generated Search Keywords

# %%
for i, kw in enumerate(results['search_keywords'], 1):
    print(f"{i}. {kw}")
# Out:
# ================================================================================
# GENERATED SEARCH KEYWORDS
# ================================================================================
# 1. Apple iPhone early release rumors 2024
# 2. iPhone 16 production schedule leak
# 3. Apple spring product launch event 2024
# 4. iPhone new model prototype unveiling
# 5. Apple deviates from September release tradition
# ================================================================================

# %% [markdown]
# ### All Retrieved News Articles (with Ratings)
#
# All articles retrieved and rated by the pipeline, sorted by relevance rating.

# %%
print("\n" + "="*80)
print(f"ALL RETRIEVED NEWS ARTICLES ({len(results['all_rated_news'])} total)")
print("="*80)

if results['all_rated_news']:
    for i, article in enumerate(results['all_rated_news'], 1):
        print(f"\n{i}. [RATING: {article['relevance_rating']}/5]")
        print(f"   Title: {article.get('title', 'N/A')}")
        print(f"   Publisher: {article.get('publisher', {}).get('title', 'N/A') if isinstance(article.get('publisher'), dict) else 'N/A'}")
        print(f"   Date: {article.get('published date', 'N/A')}")
        print(f"   URL: {article.get('url', 'N/A')}")
        print(f"   Description: {article.get('description', 'N/A')[:200]}...")
        print(f"   Search Query: {article.get('search_query', 'N/A')[:60]}...")
else:
    print("No articles retrieved.")
print("\n" + "="*80)
# Out:
# ================================================================================
# ALL RETRIEVED NEWS ARTICLES (9 total)
# ================================================================================
#
# 1. [RATING: 4/5]
#    Title: iPhone 16 in 2024 — here's everything Apple could announce this year - Tom's Guide
#    Publisher: Tom's Guide
#    Date: Sun, 31 Dec 2023 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMiWEFVX3lxTE5kbVNNWko2eDhXdkh3aWlieXhLX29BZUxiaHhsUFF3ZF9OSFNkVzVsVVNpdFhlZHF4UGVnWGMxWUhXdDItWDgwdkhfVUtGRE5UOHFmTTRuRXY?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: iPhone 16 in 2024 — here's everything Apple could announce this year  Tom's Guide...
#    Search Query: Apple iPhone early release rumors 2024...
#
# 2. [RATING: 4/5]
#    Title: Leaked iPhone 16 design is giving me major 2017 vibes - Creative Bloq
#    Publisher: Creative Bloq
#    Date: Wed, 07 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMiX0FVX3lxTE9aUURaUElVWGtyWFZoaE14MEpYdXphN2w4QTlZSmVMdE13REY0dVNaQjJaaGtjTnR1dUxJUW1zU185Q21iQm5iMjgwSmZud0h2V2t3N0FXdThLeEZvZkRr?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Leaked iPhone 16 design is giving me major 2017 vibes  Creative Bloq...
#    Search Query: iPhone 16 production schedule leak...
#
# 3. [RATING: 4/5]
#    Title: Apple March event: Everything we know so far - 9to5Mac
#    Publisher: 9to5Mac
#    Date: Wed, 14 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMigAFBVV95cUxNdF9wNzA5TWd1eHlyYlJ6NUZiYU95YUhRcmZwTG9hZDR3OUoxWWJqUHlYQ01oeEJuQmlmV2JSWGVYbl9GaVlWV01aYlE5djdNSkhLRkpuYmxLNjNPRGEtcVQ0Sy1taWQ0dmJSTWk2cXM4a05xUng4bnYtQTRSYUU5aQ?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple March event: Everything we know so far  9to5Mac...
#    Search Query: Apple spring product launch event 2024...
#
# 4. [RATING: 4/5]
#    Title: Early iPhone 16 Prototype Unveils Updated Design, Is It Truly Innovative? — Let’s Find Out - Mashable India
#    Publisher: Mashable India
#    Date: Wed, 13 Dec 2023 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Early iPhone 16 Prototype Unveils Updated Design, Is It Truly Innovative? — Let’s Find Out  Mashable India...
#    Search Query: iPhone new model prototype unveiling...
#
# 5. [RATING: 4/5]
#    Title: Leaked iPhone 16 ‘prototypes’ point to possible return of vertical camera layout - Macworld
#    Publisher: Macworld
#    Date: Wed, 13 Dec 2023 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMikgFBVV95cUxQSng1NzZSVm5IaUV5b0VLUVlLTFhYc29HLWhxM3BuNy02Z0x2VjhRM0pUZWtRWVlIM3Rpb09hRmlhbHRLMll1TllDbm5oVlhORHFBcU91enhhMU02T01QY3JEdncyUG9kZmI4bFhQNXFkS0lpUjFDU3Y4WlVic3RiM1pBYkZ2NTJTb05PajFLN3M3dw?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Leaked iPhone 16 ‘prototypes’ point to possible return of vertical camera layout  Macworld...
#    Search Query: iPhone new model prototype unveiling...
#
# 6. [RATING: 2/5]
#    Title: Apple announces changes to iOS, Safari, and the App Store in the European Union - Apple
#    Publisher: Apple
#    Date: Thu, 25 Jan 2024 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple announces changes to iOS, Safari, and the App Store in the European Union  Apple...
#    Search Query: Will Apple release a new iPhone model before June 2024?...
#
# 7. [RATING: 2/5]
#    Title: How the Apple iPhone became one of the best-selling products of all time - CNBC
#    Publisher: CNBC
#    Date: Sat, 27 Jan 2024 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: How the Apple iPhone became one of the best-selling products of all time  CNBC...
#    Search Query: Will Apple release a new iPhone model before June 2024?...
#
# 8. [RATING: 2/5]
#    Title: Apple Vision Pro available in the U.S. on February 2 - Apple
#    Publisher: Apple
#    Date: Mon, 08 Jan 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMilAFBVV95cUxNMDU0LUxSY1JqRU1va0JhTHZoMDNad1Y2OURHaC1yb0MtUnhJVFlKWVhCZDdiRjc1Z2Y3S3lDNW5LMEZZakhQM2g0a2EwWWVwcTJLWmpvVEw4Y0Jabks5UkxjV3pGNkM5TDk2SGRjY1dNUlFJNDd0dGNTNG5tVGFhMHg4MGdvX0pGbHVyMjdKc3UxeWZG?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple Vision Pro available in the U.S. on February 2  Apple...
#    Search Query: Apple iPhone early release rumors 2024...
#
# 9. [RATING: 2/5]
#    Title: iPhone 16 leak reveals Apple may have ditched bold design change for more of the same - iMore
#    Publisher: iMore
#    Date: Wed, 13 Dec 2023 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: iPhone 16 leak reveals Apple may have ditched bold design change for more of the same  iMore...
#    Search Query: iPhone 16 production schedule leak...
#
# ================================================================================

# %% [markdown]
# ### News Summary (Synthesized Analysis)
#
# This summary synthesizes all articles with rating >= minimum threshold into a single cohesive analysis. The summary identifies key factors affecting the forecasting question by combining insights from all relevant articles, eliminating redundant information, and focusing on verifiable facts without editorial opinions.

# %%
print("\n" + "="*80)
print(f"NEWS SUMMARY (Only articles with rating >= {pipeline_config['min_news_rating']})")
print("="*80)
print(f"\nRelevant articles: {len(results['relevant_news'])}/{len(results['all_rated_news'])}\n")
print(results['summary'])
print("\n" + "="*80)
# Out:
# ================================================================================
# NEWS SUMMARY (Only articles with rating >= 3)
# ================================================================================
#
# Relevant articles: 5/9
#
# Apple's iPhone plans for 2024 are underway, with the company accounting for 52% of its $383 billion in sales in its 2023 fiscal year. The iPhone 15 models, released in the fall of 2023, featured significant upgrades, including the adoption of the Dynamic Island feature and a 48MP main camera on the standard model. The iPhone 15 Pro models had a lighter titanium frame and a powerful A17 Pro chipset, with the iPhone 15 Pro Max offering 256GB of storage and a redesigned telephoto lens.
#
# Apple has a history of releasing new iPhone models in September of each year. In 2024, the company is rumored to be working on new models, with leaked schematics indicating a possible return to a vertical camera layout, similar to the iPhone 12. The design may also feature a slimmer cutout and rounded edges, reminiscent of the iPhone X. Additionally, the Action Button, currently limited to the iPhone 15 Pro, may be introduced to the entire iPhone 16 lineup, along with a new "Capture" button dedicated to shooting video.
#
# In the first half of 2024, Apple is expected to focus on other product releases, including the Apple Vision Pro, a spatial computing headset, which may be launched in February. The company may also hold a March event, where it could unveil new iPads and a revised MacBook Air. Historically, Apple has held spring events in March or April, focusing on Mac and iPad products, in addition to its annual WWDC event in June and the September iPhone event.
#
# There is no confirmed information on the release date of the iPhone 16, but based on historical patterns, it is likely to be released in September 2024. The exact design and features of the new iPhone model have not been officially announced, but leaked prototypes and rumors indicate significant changes, including an updated camera layout and new hardware buttons.
#
# ================================================================================
