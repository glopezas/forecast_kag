# %% [markdown]
# # News Retrieval Pipeline for Forecasting
#
# This notebook demonstrates the news retrieval pipeline that uses LLMs to:
# 1. **Generate search keywords** optimized for Google News
# 2. **Retrieve relevant news** articles using the generated keywords
# 3. **Rate the relevance** of each news article (1-5 scale)
# 4. **Synthesize all relevant news** into a single cohesive summary

# %% [markdown]
# ## Select a Question

# %%
question = "Will Apple release a new iPhone model before June 2024?"
background = "Apple typically releases new iPhone models in September each year."
question_date = "2024-03-01"

# %% [markdown]
# ## Initialize and Run Pipeline
#
# Set parameters for the news retrieval pipeline.

# %%
# Pipeline configuration
pipeline_config = {
    'num_keywords': 4,            # Number of search keywords to generate
    'news_per_keyword': 2,        # News articles to retrieve per keyword
    'min_news_rating': 3,         # Minimum relevance rating (1-5) to keep articles
    'news_period_days': 90,       # How many days back to search for news
    'question_gen_temp': 0.7,     # Temperature for keyword generation
    'news_rating_temp': 0.3,      # Temperature for news rating
    'summarization_temp': 0.5,    # Temperature for summarization
    'max_tokens': 1000            # Max tokens for LLM responses
}

# %%
from forecast_kag.news_retrieval import NewsRetrievalPipeline
# Initialize pipeline
print(f"Initializing pipeline...\n")
pipeline = NewsRetrievalPipeline(
    model_shortname="qwen80",
    **pipeline_config
)

# Run pipeline
print("="*80)
results = pipeline.run(
    question=question,
    background=background,
    question_date=question_date
)
print("="*80)
# Out:
# 11/16/2025 12:20:58 PM - ================================================================================
# 11/16/2025 12:20:58 PM - NEWS RETRIEVAL PIPELINE
# 11/16/2025 12:20:58 PM - ================================================================================
# 11/16/2025 12:20:58 PM - Question: Will Apple release a new iPhone model before June 2024?
# 11/16/2025 12:20:58 PM - Date Range: 90 days
# 11/16/2025 12:20:58 PM - ================================================================================
# 11/16/2025 12:20:58 PM - News search cutoff date: 2024-03-01
# 11/16/2025 12:20:58 PM - Searching news from 2023-12-02 to 2024-03-01
# 11/16/2025 12:20:58 PM - [Agent 1: Keyword Generation] Generating 4 search keywords...
# 11/16/2025 12:20:58 PM - Calling LLM for Keyword Generation...
# Initializing pipeline...
#
# ================================================================================
# 11/16/2025 12:20:59 PM - Keyword Generation completed
# 11/16/2025 12:20:59 PM - Generated 4 search keywords
# 11/16/2025 12:20:59 PM -   1. Apple iPhone 16 launch date 2024
# 11/16/2025 12:20:59 PM -   2. Apple supply chain iPhone 16 production
# 11/16/2025 12:20:59 PM -   3. Apple FCC iPhone 16 certification
# 11/16/2025 12:20:59 PM -   4. Apple product roadmap 2024 leak
# 11/16/2025 12:20:59 PM -
# [Agent 2: News Retrieval] Preparing search queries...
# 11/16/2025 12:20:59 PM - Original question: 'Will Apple release a new iPhone model before June 2024?...'
# 11/16/2025 12:20:59 PM - Total search queries: 5 (1 original + 4 keywords)
# 11/16/2025 12:20:59 PM - Executing 5 news searches...
# 11/16/2025 12:20:59 PM - Query 1/5 [ORIGINAL]: 'Will Apple release a new iPhone model before June 2024?...'
# 11/16/2025 12:21:01 PM - Found 2 articles
# 11/16/2025 12:21:27 PM -
# 5 articles meet threshold (rating >= 3)
# 11/16/2025 12:21:27 PM -
# [Agent 4: Summarization] Synthesizing 5 articles into cohesive summary...
# 11/16/2025 12:21:27 PM - Calling LLM for Article Synthesis...
# 11/16/2025 12:21:30 PM - Article Synthesis completed
# 11/16/2025 12:21:30 PM - Synthesis completed (1085 characters)
# 11/16/2025 12:21:30 PM -
# ================================================================================
# 11/16/2025 12:21:30 PM - PIPELINE COMPLETED SUCCESSFULLY
# 11/16/2025 12:21:30 PM - ================================================================================
# ================================================================================

# %% [markdown]
# ## Display Results

# %% [markdown]
# ### Pipeline Statistics

# %%
print("\n" + "="*80)
print("PIPELINE STATISTICS")
print("="*80)
for key, value in results['stats'].items():
    print(f"{key}: {value}")
print("="*80)
# Out:
# ================================================================================
# PIPELINE STATISTICS
# ================================================================================
# num_search_keywords: 4
# total_articles_retrieved: 9
# total_articles_rated: 9
# relevant_articles: 5
# min_rating_threshold: 3
# ================================================================================

# %% [markdown]
# ### Generated Search Keywords

# %%
print("\n" + "="*80)
print("GENERATED SEARCH KEYWORDS")
print("="*80)
for i, kw in enumerate(results['search_keywords'], 1):
    print(f"{i}. {kw}")
print("="*80)
# Out:
# ================================================================================
# GENERATED SEARCH KEYWORDS
# ================================================================================
# 1. Apple iPhone 16 launch date 2024
# 2. Apple supply chain iPhone 16 production
# 3. Apple FCC iPhone 16 certification
# 4. Apple product roadmap 2024 leak
# ================================================================================

# %% [markdown]
# ### All Retrieved News Articles (with Ratings)
#
# All articles retrieved and rated by the pipeline, sorted by relevance rating.

# %%
print("\n" + "="*80)
print(f"ALL RETRIEVED NEWS ARTICLES ({len(results['all_rated_news'])} total)")
print("="*80)

if results['all_rated_news']:
    for i, article in enumerate(results['all_rated_news'], 1):
        print(f"\n{i}. [RATING: {article['relevance_rating']}/5]")
        print(f"   Title: {article.get('title', 'N/A')}")
        print(f"   Publisher: {article.get('publisher', {}).get('title', 'N/A') if isinstance(article.get('publisher'), dict) else 'N/A'}")
        print(f"   Date: {article.get('published date', 'N/A')}")
        print(f"   URL: {article.get('url', 'N/A')}")
        print(f"   Description: {article.get('description', 'N/A')[:200]}...")
        print(f"   Search Query: {article.get('search_query', 'N/A')[:60]}...")
else:
    print("No articles retrieved.")
print("\n" + "="*80)
# Out:
# ================================================================================
# ALL RETRIEVED NEWS ARTICLES (9 total)
# ================================================================================
#
# 1. [RATING: 4/5]
#    Title: iPhone 16 in 2024 — here's everything Apple could announce this year - Tom's Guide
#    Publisher: Tom's Guide
#    Date: Sun, 31 Dec 2023 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMiWEFVX3lxTE5kbVNNWko2eDhXdkh3aWlieXhLX29BZUxiaHhsUFF3ZF9OSFNkVzVsVVNpdFhlZHF4UGVnWGMxWUhXdDItWDgwdkhfVUtGRE5UOHFmTTRuRXY?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: iPhone 16 in 2024 — here's everything Apple could announce this year  Tom's Guide...
#    Search Query: Apple iPhone 16 launch date 2024...
#
# 2. [RATING: 4/5]
#    Title: iPhone 16 Ultra: Release date rumors, news, and more - iMore
#    Publisher: iMore
#    Date: Mon, 05 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMihAFBVV95cUxQS0FxU1ZZQjlaUTdsakIzbVpCVkk2eHlqZ0tacFlQMTBDanVodzdJN1pKQzlGdEdQM2hIdUwzTHEyNk9mdzZlNWVSTU1lVHFHYmlyVUc4ek5jVXJiV0lZbklnLW8zaGdibDFqOGtCRm1NU1dyMzI1aEtFOEdhNDhoVGFIalM?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: iPhone 16 Ultra: Release date rumors, news, and more  iMore...
#    Search Query: Apple iPhone 16 launch date 2024...
#
# 3. [RATING: 4/5]
#    Title: China Set To Lose Out to India in Apple’s iPhone 16 - Newsweek
#    Publisher: Newsweek
#    Date: Thu, 07 Dec 2023 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMilgFBVV95cUxOWUtONGFTckRiSlpjUHdCY2x4S2xhV3p1WEI1VmFnaWdOZjdVZ0pXU2txWWJjeGcyUkpXcHQwZ25QNElNRmpPZ3dQV3ZkVVFqZTk0ZlVZY2tTVDhYSl9KaDhRa1NvdGJvbnpQcl9Vend0SEhFdElhdGlRdG93b1pnWFcxeVphaTBHdFRqeTgyU2UwU2t0a0E?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: China Set To Lose Out to India in Apple’s iPhone 16  Newsweek...
#    Search Query: Apple supply chain iPhone 16 production...
#
# 4. [RATING: 4/5]
#    Title: New Apple leak suggests M3 MacBook Air and iPad Pro models are landing very soon - TechRadar
#    Publisher: TechRadar
#    Date: Wed, 28 Feb 2024 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: New Apple leak suggests M3 MacBook Air and iPad Pro models are landing very soon  TechRadar...
#    Search Query: Apple product roadmap 2024 leak...
#
# 5. [RATING: 3/5]
#    Title: Apple moves towards India-made iPhone batteries in push away from China - Financial Times
#    Publisher: Financial Times
#    Date: Tue, 05 Dec 2023 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMicEFVX3lxTE4xbG5RRGQyVmpES2stRGYyOWNqY2lzWGFOTWFLRFlQaUJmT1dFcmZvVTNtdHRMeWlaYmU3UDhkSEVEdGlVV2FRUll6TzVhT1Nqdkgyb0VYZjJDSm9samN5U3RRM3hoV0xsaS1lal9rWTU?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple moves towards India-made iPhone batteries in push away from China  Financial Times...
#    Search Query: Apple supply chain iPhone 16 production...
#
# 6. [RATING: 2/5]
#    Title: How the Apple iPhone became one of the best-selling products of all time - CNBC
#    Publisher: CNBC
#    Date: Sat, 27 Jan 2024 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: How the Apple iPhone became one of the best-selling products of all time  CNBC...
#    Search Query: Will Apple release a new iPhone model before June 2024?...
#
# 7. [RATING: 2/5]
#    Title: Photo shows why iPhone 15 series owners need to use a genuine Apple or Apple-certified (MFi) charger - PhoneArena
#    Publisher: PhoneArena
#    Date: Sun, 24 Dec 2023 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMihAFBVV95cUxQU3BtQ21zZUNRZXJnLXg3Nm44a2tWU0Q4aHNTWFdvU1hkNzRnUnBWN3UzcDRBU3Y1UEVHaF9HTWtkM0tmVHVOOXJnbDk4UkNRNHphek0zSGRXaHhhT0hkOE5jdTVPamVUZ3Z0REtNbGswVnl4WkVjLWNUUVJNSE1QZEpxT0g?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Photo shows why iPhone 15 series owners need to use a genuine Apple or Apple-certified (MFi) charger  PhoneArena...
#    Search Query: Apple FCC iPhone 16 certification...
#
# 8. [RATING: 2/5]
#    Title: Leaked Apple OLED iPad And MacBook Roadmap Could Point To Major Design Changes - bgr.com
#    Publisher: bgr.com
#    Date: Wed, 21 Feb 2024 08:00:00 GMT
#    URL: https://news.google.com/rss/articles/CBMipwFBVV95cUxQc0ZlMlRTQUVVQ1NCbU40U21ocm1Ea3BIRTJPUkhicGtDaWZHYVJiYTJoQUtENWVnNldXT2Z3TV9BbFdSd2dsb29xY0wzSng0QVl1dk1UeE84dDF6QUxaT29ZV1FWeHByZzcwRG1oTzU3c1czTU1yRUNBUlN5ZFpXQnd5czlSeU42SzNEUmNwbkFSNnR1eUl3ZzRVTVUtYno1NW54a0NiTQ?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Leaked Apple OLED iPad And MacBook Roadmap Could Point To Major Design Changes  bgr.com...
#    Search Query: Apple product roadmap 2024 leak...
#
# 9. [RATING: 1/5]
#    Title: Apple TV+ unveils a sneak peek at star-studded lineup of new and returning original series set to debut in 2024 - Apple
#    Publisher: Apple
#    Date: Mon, 05 Feb 2024 08:00:00 GMT
#    URL: https://news.google.?oc=5&hl=en-US&gl=US&ceid=US:en
#    Description: Apple TV+ unveils a sneak peek at star-studded lineup of new and returning original series set to debut in 2024  Apple...
#    Search Query: Will Apple release a new iPhone model before June 2024?...
#
# ================================================================================

# %% [markdown]
# ### News Summary (Synthesized Analysis)
#
# This summary synthesizes all articles with rating >= minimum threshold into a single cohesive analysis. The summary identifies key factors affecting the forecasting question by combining insights from all relevant articles, eliminating redundant information, and focusing on verifiable facts without editorial opinions.

# %%
print("\n" + "="*80)
print(f"NEWS SUMMARY (Only articles with rating >= {pipeline_config['min_news_rating']})")
print("="*80)
print(f"\nRelevant articles: {len(results['relevant_news'])}/{len(results['all_rated_news'])}\n")
print(results['summary'])
print("\n" + "="*80)
# Out:
# ================================================================================
# NEWS SUMMARY (Only articles with rating >= 3)
# ================================================================================
#
# Relevant articles: 5/9
#
# Apple has historically released new iPhone models in September each year. Reports indicate that Apple is developing new iPhone models for 2024, referred to as the iPhone 16 and potentially an iPhone 16 Ultra, with all indications pointing to a release in September 2024 alongside the usual iPhone event. No announcement or evidence has been presented of a release prior to September 2024.
#
# Apple is also advancing supply chain changes for its 2024 iPhone models, including the relocation of battery production to India through partnerships with suppliers such as TDK and Simplo Technology, as part of a broader strategy to reduce dependence on Chinese manufacturing. These changes are tied to the upcoming iPhone 16 models but do not alter the established release timeline.
#
# No credible reports confirm any iPhone model release before September 2024. Other product updates, such as the Apple Vision Pro set for February 2024 and new iPad and MacBook Air models anticipated in spring 2024, are separate from the iPhone lineup and do not indicate a change to the iPhone release schedule.
#
# ================================================================================
