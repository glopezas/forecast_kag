# %% [markdown]
# ## Configuration
#
# Set your parameters for the pipeline run.

# %%
# Pipeline Configuration
config = {
    "topic": "Films and TV Shows",                # Broad topic to explore
    "simulated_date": "2024-07-01",     # The "present" we're simulating (July 2024)
    "num_questions": 100,                # How many questions to generate
    "num_categories": 20,                # Number of main categories
    "buffer_days": 7,                   # Safety buffer (Question_Date = Resolution_Date - buffer_days)
    
    # Model Selection
    # Available models: llama70, alcf_oss120b, alcf_oss20b, gemma-3-27b-it
    "architect_model": "llama70",        # Model for taxonomy expansion
    "historian_model": "llama70",        # Model for question generation
    "critic_model": "llama70",           # Model for validation
    
    # Output files
    "output_file": "data/movie_questions.jsonl",
    "discarded_file": "data/discarded_movie_questions.jsonl",
    "checkpoint_file": "logs/completed_log.txt"
}

print("Configuration:")
print("="*60)
for key, value in config.items():
    print(f"{key:20s}: {value}")
print("="*60)
# Out:
# Configuration:
# ============================================================
# topic               : Politics
# simulated_date      : 2024-07-01
# num_questions       : 100
# num_categories      : 20
# buffer_days         : 7
# architect_model     : llama70
# historian_model     : llama70
# critic_model        : llama70
# output_file         : data/generated_questions.jsonl
# discarded_file      : data/discarded_questions.jsonl
# checkpoint_file     : logs/completed_log.txt
# ============================================================

# %% [markdown]
# ## Initialize Pipeline
#
# Import the pipeline and create an instance with your chosen models.

# %%
from forecast_kag.question_generation_pipeline import ForecastingQuestionPipeline

# Initialize pipeline
pipeline = ForecastingQuestionPipeline(
    architect_model=config['architect_model'],
    historian_model=config['historian_model'],
    critic_model=config['critic_model'],
    buffer_days=config['buffer_days'],
    output_file=config['output_file'],
    discarded_file=config['discarded_file'],
    checkpoint_file=config['checkpoint_file']
)
# Out:
# 2025-11-30 14:41:01 - INFO - ================================================================================
# 2025-11-30 14:41:01 - INFO - FORECASTING QUESTION GENERATION PIPELINE INITIALIZED
# 2025-11-30 14:41:01 - INFO - ================================================================================
# 2025-11-30 14:41:01 - INFO - Architect Model: llama70
# 2025-11-30 14:41:01 - INFO - Historian Model: llama70
# 2025-11-30 14:41:01 - INFO - Critic Model: llama70
# 2025-11-30 14:41:01 - INFO - Safety Buffer: 7 days
# 2025-11-30 14:41:01 - INFO - Min Resolution Buffer: 30 days (ensures information is available)
# 2025-11-30 14:41:01 - INFO - ================================================================================

# %% [markdown]
# ## Run Pipeline
#
# Execute the complete pipeline. This will:
# 1. Expand the topic into categories/subcategories
# 2. Generate questions for each subcategory
# 3. Validate each question independently
# 4. Save validated questions to JSONL
#
# **Note**: This may take several minutes depending on `num_questions` and API response times.

# %%
# Run the pipeline
try:
    stats = pipeline.run(
        topic=config['topic'],
        simulated_date=config['simulated_date'],
        num_questions=config['num_questions'],
        num_categories=config['num_categories']
    )
except Exception as e:
    print(f"\n{'='*80}")
    print("ERROR: Pipeline execution failed")
    print(f"{'='*80}")
    print(f"Error: {str(e)}")
    print(f"\nTroubleshooting:")
    print("1. Check that your model servers are running and accessible")
    print("2. Verify models/model_servers.yaml has correct endpoints")
    print("3. Try reducing num_questions to a smaller number (e.g., 3)")
    print("4. Check your internet connection for search functionality")
    print(f"{'='*80}")
    raise
# Out:
# 2025-11-30 14:41:01 - INFO -
# ================================================================================
# 2025-11-30 14:41:01 - INFO - PIPELINE EXECUTION STARTED
# 2025-11-30 14:41:01 - INFO - ================================================================================
# 2025-11-30 14:41:01 - INFO - Topic: Politics
# 2025-11-30 14:41:01 - INFO - Simulated Date: 2024-07-01
# 2025-11-30 14:41:01 - INFO - Current Date: 2025-11-30
# 2025-11-30 14:41:01 - INFO - Target Questions: 100
# 2025-11-30 14:41:01 - INFO - ================================================================================
#
# 2025-11-30 14:41:01 - INFO - ================================================================================
# 2025-11-30 14:41:01 - INFO - [MODULE A: THE ARCHITECT] Taxonomy Expansion
# 2025-11-30 14:41:01 - INFO - ================================================================================
# 2025-11-30 14:41:01 - INFO - Topic: Politics
# 2025-11-30 14:41:01 - INFO - Generating 20 categories with 5 subcategories each
# 2025-11-30 14:41:01 - INFO - Calling LLM for Taxonomy Expansion...
# 2025-11-30 14:41:30 - INFO - Taxonomy Expansion completed
# 2025-11-30 14:41:30 - INFO - Generated 19 categories
# 2025-11-30 14:41:30 - INFO -   - Elections: complexity=9, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Government Policies: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - International Relations: complexity=9, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Political Scandals: complexity=7, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Supreme Court Decisions: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Legislative Actions: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Public Protests: complexity=6, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Economic Sanctions: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Military Conflicts: complexity=9, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Immigration Policies: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Environmental Policies: complexity=7, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Healthcare Policies: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Education Policies: complexity=7, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Infrastructure Development: complexity=7, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Cybersecurity Measures: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Disaster Response: complexity=7, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Space Exploration: complexity=6, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Artificial Intelligence Regulations: complexity=8, subcategories=5
# 2025-11-30 14:41:30 - INFO -   - Global Governance: complexity=9, subcategories=5
# 2025-11-30 14:41:30 - INFO -
# ================================================================================
# 2025-11-30 14:41:30 - INFO - QUESTION BUDGET ALLOCATION (by complexity)
# 2025-11-30 14:41:30 - INFO - ================================================================================
# 2025-11-30 14:41:30 - INFO -   Elections: 6 questions
# 2025-11-30 14:41:30 - INFO -   Government Policies: 5 questions
# 2025-11-30 14:41:30 - INFO -   International Relations: 6 questions
# 2025-11-30 14:41:30 - INFO -   Political Scandals: 4 questions
# 2025-11-30 14:41:30 - INFO -   Supreme Court Decisions: 5 questions
# 2025-11-30 14:41:30 - INFO -   Legislative Actions: 5 questions
# 2025-11-30 14:41:30 - INFO -   Public Protests: 4 questions
# 2025-11-30 14:41:30 - INFO -   Economic Sanctions: 5 questions
# 2025-11-30 14:41:30 - INFO -   Military Conflicts: 6 questions
# 2025-11-30 14:41:30 - INFO -   Immigration Policies: 5 questions
# 2025-11-30 14:41:30 - INFO -   Environmental Policies: 4 questions
# 2025-11-30 14:41:30 - INFO -   Healthcare Policies: 5 questions
# 2025-11-30 14:41:30 - INFO -   Education Policies: 4 questions
# 2025-11-30 14:41:30 - INFO -   Infrastructure Development: 4 questions
# 2025-11-30 14:41:30 - INFO -   Cybersecurity Measures: 5 questions
# 2025-11-30 14:41:30 - INFO -   Disaster Response: 4 questions
# 2025-11-30 14:41:30 - INFO -   Space Exploration: 4 questions
# 2025-11-30 14:41:30 - INFO -   Artificial Intelligence Regulations: 5 questions
# 2025-11-30 14:41:30 - INFO -   Global Governance: 6 questions
# 2025-11-30 14:41:30 - INFO - ================================================================================
#
# 2025-11-30 14:41:30 - INFO -
# ================================================================================
# 2025-11-30 14:41:30 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Elections
# 2025-11-30 14:41:30 - INFO - ================================================================================
# 2025-11-30 14:41:30 - INFO - Complexity: 9/10 | Budget: 6 questions
# 2025-11-30 14:41:30 - INFO - ================================================================================
#
# 2025-11-30 14:41:30 - INFO -
# → Processing subcategory: US Presidential Election Results
# 2025-11-30 14:41:30 - INFO -   Attempt 1/3
# 2025-11-30 14:41:36 - INFO - Search found 10 results for query: 'Joe Biden Elections 2024...'
# 2025-11-30 14:41:38 - INFO -   Validating: Will Joe Biden announce his candidacy for the 2024 US Presid...
# 2025-11-30 14:41:40 - INFO - Search found 10 results for query: 'Will Joe Biden announce his candidacy for the 2024 US Presid...'
# 2025-11-30 14:41:43 - INFO - ✓ Saved question: Will Joe Biden announce his candidacy for the 2024 US Presidential Election befo...
# 2025-11-30 14:41:43 - INFO -   Attempt 2/3
# 2025-11-30 14:41:45 - WARNING - Deadline 2024-06-30 is before simulated date
# 2025-11-30 14:41:45 - INFO -   Attempt 3/3
# 2025-11-30 14:41:47 - WARNING - Deadline 2024-06-30 is before simulated date
# 2025-11-30 14:41:47 - INFO -
# → Processing subcategory: European Parliamentary Election Outcomes
# 2025-11-30 14:41:47 - INFO -   Attempt 1/3
# 2025-11-30 14:41:49 - WARNING - Deadline 2024-06-10 is before simulated date
# 2025-11-30 14:41:49 - INFO -   Attempt 2/3
# 2025-11-30 14:41:52 - WARNING - Deadline 2024-06-15 is before simulated date
# 2025-11-30 14:41:52 - INFO -   Attempt 3/3
# 2025-11-30 14:41:57 - INFO - Search found 10 results for query: 'European People's Party Elections 2025...'
# 2025-11-30 14:41:59 - INFO -   Validating: Will the European People's Party win the most seats in the E...
# 2025-11-30 14:42:02 - INFO - Search found 10 results for query: 'Will the European People's Party win the most seats in the E...'
# 2025-11-30 14:42:04 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:42:04 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:42:04 - INFO -
# → Processing subcategory: National Leadership Elections
# 2025-11-30 14:42:04 - INFO -   Attempt 1/3
# 2025-11-30 14:42:09 - INFO - Search found 10 results for query: 'Joe Biden Elections 2024...'
# 2025-11-30 14:42:11 - INFO -   Validating: Will Joe Biden announce his candidacy for the 2024 United St...
# 2025-11-30 14:42:14 - INFO - Search found 10 results for query: 'Will Joe Biden announce his candidacy for the 2024 United St...'
# 2025-11-30 14:42:17 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:42:17 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:42:17 - INFO -   Attempt 2/3
# 2025-11-30 14:42:19 - WARNING - Deadline 2024-03-15 is before simulated date
# 2025-11-30 14:42:19 - INFO -   Attempt 3/3
# 2025-11-30 14:42:21 - WARNING - Deadline 2024-03-15 is before simulated date
# 2025-11-30 14:42:21 - INFO -
# → Processing subcategory: State Governor Elections
# 2025-11-30 14:42:21 - INFO -   Attempt 1/3
# 2025-11-30 14:42:26 - INFO - Search found 10 results for query: 'Gavin Newsom Elections 2024...'
# 2025-11-30 14:42:28 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:42:28 - INFO -   Attempt 2/3
# 2025-11-30 14:42:30 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:42:30 - INFO -   Attempt 3/3
# 2025-11-30 14:42:35 - INFO - Search found 10 results for query: 'Gavin Newsom Elections 2024...'
# 2025-11-30 14:42:37 - INFO -   Validating: Will Gavin Newsom announce his candidacy for California Gove...
# 2025-11-30 14:42:40 - INFO - Search found 10 results for query: 'Will Gavin Newsom announce his candidacy for California Gove...'
# 2025-11-30 14:42:42 - INFO - ✓ Saved question: Will Gavin Newsom announce his candidacy for California Governor before October ...
# 2025-11-30 14:42:42 - INFO -
# → Processing subcategory: Local Mayoral Elections
# 2025-11-30 14:42:42 - INFO -   Attempt 1/3
# 2025-11-30 14:42:44 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:42:44 - INFO -   Attempt 2/3
# 2025-11-30 14:42:49 - INFO - Search found 10 results for query: 'Eric Adams Elections 2024...'
# 2025-11-30 14:42:51 - INFO -   Validating: Will Eric Adams win the New York City mayoral election befor...
# 2025-11-30 14:42:54 - INFO - Search found 10 results for query: 'Will Eric Adams win the New York City mayoral election befor...'
# 2025-11-30 14:42:56 - INFO - ✓ Saved question: Will Eric Adams win the New York City mayoral election before November 4, 2024?...
# 2025-11-30 14:42:56 - INFO -   Attempt 3/3
# 2025-11-30 14:43:01 - INFO - Search found 10 results for query: 'Brandon Johnson Elections 2025...'
# 2025-11-30 14:43:03 - ERROR - Failed to parse answer search response: time data '2023' does not match format '%Y-%m-%d'
# 2025-11-30 14:43:03 - INFO -
# ================================================================================
# 2025-11-30 14:43:03 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Government Policies
# 2025-11-30 14:43:03 - INFO - ================================================================================
# 2025-11-30 14:43:03 - INFO - Complexity: 8/10 | Budget: 5 questions
# 2025-11-30 14:43:03 - INFO - ================================================================================
#
# 2025-11-30 14:43:03 - INFO -
# → Processing subcategory: US Federal Budget Approvals
# 2025-11-30 14:43:03 - INFO -   Attempt 1/3
# 2025-11-30 14:43:08 - INFO - Search found 10 results for query: 'US Congress Government Policies 2024...'
# 2025-11-30 14:43:10 - INFO -   Validating: Will the US Congress approve the federal budget for 2025 bef...
# 2025-11-30 14:43:13 - INFO - Search found 10 results for query: 'Will the US Congress approve the federal budget for 2025 bef...'
# 2025-11-30 14:43:16 - INFO - ✓ Saved question: Will the US Congress approve the federal budget for 2025 before October 1, 2024?...
# 2025-11-30 14:43:16 - INFO -   Attempt 2/3
# 2025-11-30 14:43:21 - INFO - Search found 10 results for query: 'The Biden Administration Government Policies 2025...'
# 2025-11-30 14:43:23 - INFO -   Validating: Will the Biden Administration announce a new federal budget ...
# 2025-11-30 14:43:26 - INFO - Search found 10 results for query: 'Will the Biden Administration announce a new federal budget ...'
# 2025-11-30 14:43:28 - WARNING - Answer mismatch - Historian: yes, Critic: no
# 2025-11-30 14:43:28 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:43:28 - INFO -   Attempt 3/3
# 2025-11-30 14:43:34 - INFO - Search found 10 results for query: 'Senate Appropriations Committee Government Policies 2024...'
# 2025-11-30 14:43:36 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:43:36 - INFO -
# → Processing subcategory: European Union Trade Agreements
# 2025-11-30 14:43:36 - INFO -   Attempt 1/3
# 2025-11-30 14:43:41 - INFO - Search found 10 results for query: 'European Commission Government Policies 2024...'
# 2025-11-30 14:43:43 - INFO -   Validating: Will the European Commission announce a new trade agreement ...
# 2025-11-30 14:43:46 - INFO - Search found 10 results for query: 'Will the European Commission announce a new trade agreement ...'
# 2025-11-30 14:43:49 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:43:49 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:43:49 - INFO -   Attempt 2/3
# 2025-11-30 14:43:54 - INFO - Search found 10 results for query: 'European Union and India Government Policies 2025...'
# 2025-11-30 14:43:57 - INFO -   Validating: Will the European Union and India finalize a free trade agre...
# 2025-11-30 14:44:00 - INFO - Search found 10 results for query: 'Will the European Union and India finalize a free trade agre...'
# 2025-11-30 14:44:02 - INFO - ✓ Saved question: Will the European Union and India finalize a free trade agreement before October...
# 2025-11-30 14:44:02 - INFO -   Attempt 3/3
# 2025-11-30 14:44:07 - INFO - Search found 10 results for query: 'European Parliament Government Policies 2025...'
# 2025-11-30 14:44:09 - INFO -   Validating: Will the European Parliament approve a comprehensive trade a...
# 2025-11-30 14:44:12 - INFO - Search found 10 results for query: 'Will the European Parliament approve a comprehensive trade a...'
# 2025-11-30 14:44:14 - INFO - ✓ Saved question: Will the European Parliament approve a comprehensive trade agreement with Austra...
# 2025-11-30 14:44:14 - INFO -
# → Processing subcategory: National Healthcare Reform Initiatives
# 2025-11-30 14:44:14 - INFO -   Attempt 1/3
# 2025-11-30 14:44:19 - INFO - Search found 10 results for query: 'The Biden Administration Government Policies 2025...'
# 2025-11-30 14:44:21 - INFO -   Validating: Will the Biden Administration announce a new national health...
# 2025-11-30 14:44:24 - INFO - Search found 10 results for query: 'Will the Biden Administration announce a new national health...'
# 2025-11-30 14:44:27 - INFO - ✓ Saved question: Will the Biden Administration announce a new national healthcare reform initiati...
# 2025-11-30 14:44:27 - INFO -   Attempt 2/3
# 2025-11-30 14:44:32 - INFO - Search found 10 results for query: 'California Government Policies 2025...'
# 2025-11-30 14:44:34 - INFO -   Validating: Will the state of California implement a single-payer health...
# 2025-11-30 14:44:37 - INFO - Search found 10 results for query: 'Will the state of California implement a single-payer health...'
# 2025-11-30 14:44:40 - INFO - ✓ Saved question: Will the state of California implement a single-payer healthcare system before O...
# 2025-11-30 14:44:40 - INFO -
# → Processing subcategory: Environmental Protection Legislation
# 2025-11-30 14:44:40 - INFO -
# → Processing subcategory: Tax Reform Bills
# 2025-11-30 14:44:40 - INFO -
# ================================================================================
# 2025-11-30 14:44:40 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: International Relations
# 2025-11-30 14:44:40 - INFO - ================================================================================
# 2025-11-30 14:44:40 - INFO - Complexity: 9/10 | Budget: 6 questions
# 2025-11-30 14:44:40 - INFO - ================================================================================
#
# 2025-11-30 14:44:40 - INFO -
# → Processing subcategory: NATO Summit Outcomes
# 2025-11-30 14:44:40 - INFO -   Attempt 1/3
# 2025-11-30 14:44:44 - INFO - Search found 10 results for query: 'NATO International Relations 2025...'
# 2025-11-30 14:44:46 - INFO -   Validating: Will NATO announce an expansion to include North Macedonia a...
# 2025-11-30 14:44:49 - INFO - Search found 10 results for query: 'Will NATO announce an expansion to include North Macedonia a...'
# 2025-11-30 14:44:52 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:44:52 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:44:52 - INFO -   Attempt 2/3
# 2025-11-30 14:44:56 - INFO - Search found 10 results for query: 'Turkey International Relations 2024...'
# 2025-11-30 14:44:58 - INFO -   Validating: Will Turkey approve Sweden's NATO membership bid before Octo...
# 2025-11-30 14:45:01 - INFO - Search found 10 results for query: 'Will Turkey approve Sweden's NATO membership bid before Octo...'
# 2025-11-30 14:45:03 - INFO - ✓ Saved question: Will Turkey approve Sweden's NATO membership bid before October 31, 2024?...
# 2025-11-30 14:45:03 - INFO -   Attempt 3/3
# 2025-11-30 14:45:09 - INFO - Search found 10 results for query: 'The United States and NATO International Relations 2025...'
# 2025-11-30 14:45:11 - INFO -   Validating: Will the United States and NATO agree on a new defense spend...
# 2025-11-30 14:45:14 - INFO - Search found 10 results for query: 'Will the United States and NATO agree on a new defense spend...'
# 2025-11-30 14:45:16 - INFO - ✓ Saved question: Will the United States and NATO agree on a new defense spending plan before Marc...
# 2025-11-30 14:45:16 - INFO -
# → Processing subcategory: G20 Meeting Agreements
# 2025-11-30 14:45:16 - INFO -   Attempt 1/3
# 2025-11-30 14:45:21 - INFO - Search found 10 results for query: 'European Union and the United States International Relations...'
# 2025-11-30 14:45:24 - ERROR - Failed to parse answer search response: time data '2025-08 (exact date not specified)' does not match format '%Y-%m-%d'
# 2025-11-30 14:45:24 - INFO -   Attempt 2/3
# 2025-11-30 14:45:29 - INFO - Search found 10 results for query: 'European Union and China International Relations 2024...'
# 2025-11-30 14:45:31 - INFO -   Validating: Will the European Union and China announce a new trade agree...
# 2025-11-30 14:45:34 - INFO - Search found 10 results for query: 'Will the European Union and China announce a new trade agree...'
# 2025-11-30 14:45:38 - INFO - ✓ Saved question: Will the European Union and China announce a new trade agreement before October ...
# 2025-11-30 14:45:38 - INFO -   Attempt 3/3
# 2025-11-30 14:45:43 - INFO - Search found 10 results for query: 'India and the United States International Relations 2025...'
# 2025-11-30 14:45:45 - INFO -   Validating: Will India and the United States finalize a bilateral trade ...
# 2025-11-30 14:45:48 - INFO - Search found 10 results for query: 'Will India and the United States finalize a bilateral trade ...'
# 2025-11-30 14:45:51 - INFO - ✓ Saved question: Will India and the United States finalize a bilateral trade pact before March 31...
# 2025-11-30 14:45:51 - INFO -
# → Processing subcategory: US-China Trade Deal Negotiations
# 2025-11-30 14:45:51 - INFO -   Attempt 1/3
# 2025-11-30 14:45:56 - INFO - Search found 10 results for query: 'The United States and China International Relations 2025...'
# 2025-11-30 14:45:58 - INFO -   Validating: Will the United States and China announce a new trade deal b...
# 2025-11-30 14:46:01 - INFO - Search found 10 results for query: 'Will the United States and China announce a new trade deal b...'
# 2025-11-30 14:46:03 - INFO - ✓ Saved question: Will the United States and China announce a new trade deal before March 31, 2025...
# 2025-11-30 14:46:03 - INFO -   Attempt 2/3
# 2025-11-30 14:46:08 - INFO - Search found 10 results for query: 'European Union International Relations 2024...'
# 2025-11-30 14:46:10 - INFO -   Validating: Will the European Union impose tariffs on Chinese goods befo...
# 2025-11-30 14:46:13 - INFO - Search found 10 results for query: 'Will the European Union impose tariffs on Chinese goods befo...'
# 2025-11-30 14:46:17 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:46:17 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:46:17 - INFO -   Attempt 3/3
# 2025-11-30 14:46:22 - INFO - Search found 10 results for query: 'Japan and China International Relations 2024...'
# 2025-11-30 14:46:24 - INFO -   Validating: Will Japan and China finalize a bilateral trade agreement be...
# 2025-11-30 14:46:27 - INFO - Search found 10 results for query: 'Will Japan and China finalize a bilateral trade agreement be...'
# 2025-11-30 14:46:31 - INFO - ✓ Saved question: Will Japan and China finalize a bilateral trade agreement before December 15, 20...
# 2025-11-30 14:46:31 - INFO -
# → Processing subcategory: European Union Summit Decisions
# 2025-11-30 14:46:32 - INFO -
# → Processing subcategory: United Nations General Assembly Resolutions
# 2025-11-30 14:46:32 - INFO -
# ================================================================================
# 2025-11-30 14:46:32 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Political Scandals
# 2025-11-30 14:46:32 - INFO - ================================================================================
# 2025-11-30 14:46:32 - INFO - Complexity: 7/10 | Budget: 4 questions
# 2025-11-30 14:46:32 - INFO - ================================================================================
#
# 2025-11-30 14:46:32 - INFO -
# → Processing subcategory: US Congressional Investigations
# 2025-11-30 14:46:32 - INFO -   Attempt 1/3
# 2025-11-30 14:46:37 - INFO - Search found 10 results for query: 'US House of Representatives Political Scandals 2025...'
# 2025-11-30 14:46:39 - INFO -   Validating: Will the US House of Representatives launch an investigation...
# 2025-11-30 14:46:42 - INFO - Search found 10 results for query: 'Will the US House of Representatives launch an investigation...'
# 2025-11-30 14:46:44 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:46:44 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:46:44 - INFO -   Attempt 2/3
# 2025-11-30 14:46:49 - INFO - Search found 10 results for query: 'US Senate Ethics Committee Political Scandals 2024...'
# 2025-11-30 14:46:51 - INFO -   Validating: Will the US Senate Ethics Committee announce an investigatio...
# 2025-11-30 14:46:54 - INFO - Search found 10 results for query: 'Will the US Senate Ethics Committee announce an investigatio...'
# 2025-11-30 14:46:58 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:46:58 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:46:58 - INFO -   Attempt 3/3
# 2025-11-30 14:47:03 - INFO - Search found 10 results for query: 'US Congressional Oversight Committee Political Scandals 2024...'
# 2025-11-30 14:47:05 - INFO -   Validating: Will the US Congressional Oversight Committee subpoena a for...
# 2025-11-30 14:47:08 - INFO - Search found 10 results for query: 'Will the US Congressional Oversight Committee subpoena a for...'
# 2025-11-30 14:47:11 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:47:11 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:47:11 - INFO -
# → Processing subcategory: European Union Corruption Cases
# 2025-11-30 14:47:11 - INFO -   Attempt 1/3
# 2025-11-30 14:47:16 - INFO - Search found 10 results for query: 'European Commission Political Scandals 2025...'
# 2025-11-30 14:47:18 - INFO -   Validating: Will the European Commission announce an investigation into ...
# 2025-11-30 14:47:21 - INFO - Search found 10 results for query: 'Will the European Commission announce an investigation into ...'
# 2025-11-30 14:47:24 - INFO - ✓ Saved question: Will the European Commission announce an investigation into corruption allegatio...
# 2025-11-30 14:47:24 - INFO -   Attempt 2/3
# 2025-11-30 14:47:29 - INFO - Search found 10 results for query: 'European Anti-Fraud Office (OLAF) Political Scandals 2024...'
# 2025-11-30 14:47:31 - ERROR - Failed to parse answer search response: time data '2024 (exact date not specified, but before October 31)' does not match format '%Y-%m-%d'
# 2025-11-30 14:47:31 - INFO -   Attempt 3/3
# 2025-11-30 14:47:37 - INFO - Search found 10 results for query: 'European Anti-Fraud Office (OLAF) Political Scandals 2024...'
# 2025-11-30 14:47:39 - WARNING - Question date 2024-06-09 00:00:00 is before simulated date
# 2025-11-30 14:47:39 - INFO -
# → Processing subcategory: National Embezzlement Scandals
# 2025-11-30 14:47:39 - INFO -   Attempt 1/3
# 2025-11-30 14:47:44 - INFO - Search found 10 results for query: 'US Department of Justice Political Scandals 2025...'
# 2025-11-30 14:47:46 - INFO -   Validating: Will the US Department of Justice announce charges against a...
# 2025-11-30 14:47:49 - INFO - Search found 10 results for query: 'Will the US Department of Justice announce charges against a...'
# 2025-11-30 14:47:51 - INFO - ✓ Saved question: Will the US Department of Justice announce charges against a high-ranking govern...
# 2025-11-30 14:47:51 - INFO -   Attempt 2/3
# 2025-11-30 14:47:56 - INFO - Search found 10 results for query: 'Nigerian government Political Scandals 2024...'
# 2025-11-30 14:47:58 - INFO -   Validating: Will the Nigerian government recover over $100 million in em...
# 2025-11-30 14:48:01 - INFO - Search found 10 results for query: 'Will the Nigerian government recover over $100 million in em...'
# 2025-11-30 14:48:04 - INFO - ✓ Saved question: Will the Nigerian government recover over $100 million in embezzled funds from f...
# 2025-11-30 14:48:04 - INFO -   Attempt 3/3
# 2025-11-30 14:48:09 - INFO - Search found 10 results for query: 'Brazilian Senate Political Scandals 2024...'
# 2025-11-30 14:48:12 - INFO -   Validating: Will the Brazilian Senate investigate and vote on impeachmen...
# 2025-11-30 14:48:15 - INFO - Search found 10 results for query: 'Will the Brazilian Senate investigate and vote on impeachmen...'
# 2025-11-30 14:48:17 - INFO - ✓ Saved question: Will the Brazilian Senate investigate and vote on impeachment of a cabinet membe...
# 2025-11-30 14:48:17 - INFO -
# → Processing subcategory: Government Official Resignations
# 2025-11-30 14:48:17 - INFO -
# → Processing subcategory: Election Interference Allegations
# 2025-11-30 14:48:17 - INFO -
# ================================================================================
# 2025-11-30 14:48:17 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Supreme Court Decisions
# 2025-11-30 14:48:17 - INFO - ================================================================================
# 2025-11-30 14:48:17 - INFO - Complexity: 8/10 | Budget: 5 questions
# 2025-11-30 14:48:17 - INFO - ================================================================================
#
# 2025-11-30 14:48:17 - INFO -
# → Processing subcategory: US Supreme Court Rulings
# 2025-11-30 14:48:17 - INFO -   Attempt 1/3
# 2025-11-30 14:48:23 - INFO - Search found 10 results for query: 'US Supreme Court Supreme Court Decisions 2025...'
# 2025-11-30 14:48:25 - INFO -   Validating: Will the US Supreme Court rule on the constitutionality of a...
# 2025-11-30 14:48:28 - INFO - Search found 10 results for query: 'Will the US Supreme Court rule on the constitutionality of a...'
# 2025-11-30 14:48:30 - INFO - ✓ Saved question: Will the US Supreme Court rule on the constitutionality of affirmative action in...
# 2025-11-30 14:48:30 - INFO -   Attempt 2/3
# 2025-11-30 14:48:36 - INFO - Search found 10 results for query: 'US Supreme Court Supreme Court Decisions 2024...'
# 2025-11-30 14:48:38 - INFO -   Validating: Will the US Supreme Court issue a ruling on the environmenta...
# 2025-11-30 14:48:41 - INFO - Search found 10 results for query: 'Will the US Supreme Court issue a ruling on the environmenta...'
# 2025-11-30 14:48:43 - INFO - ✓ Saved question: Will the US Supreme Court issue a ruling on the environmental implications of th...
# 2025-11-30 14:48:43 - INFO -   Attempt 3/3
# 2025-11-30 14:48:49 - INFO - Search found 10 results for query: 'Justice Ketanji Brown Jackson Supreme Court Decisions 2024...'
# 2025-11-30 14:48:51 - INFO -   Validating: Will Justice Ketanji Brown Jackson author a majority opinion...
# 2025-11-30 14:48:54 - INFO - Search found 10 results for query: 'Will Justice Ketanji Brown Jackson author a majority opinion...'
# 2025-11-30 14:48:56 - INFO - ✓ Saved question: Will Justice Ketanji Brown Jackson author a majority opinion in a significant ca...
# 2025-11-30 14:48:56 - INFO -
# → Processing subcategory: European Court of Justice Decisions
# 2025-11-30 14:48:56 - INFO -   Attempt 1/3
# 2025-11-30 14:49:02 - INFO - Search found 10 results for query: 'European Court of Justice Supreme Court Decisions 2025...'
# 2025-11-30 14:49:04 - INFO -   Validating: Will the European Court of Justice rule on the interpretatio...
# 2025-11-30 14:49:07 - INFO - Search found 10 results for query: 'Will the European Court of Justice rule on the interpretatio...'
# 2025-11-30 14:49:09 - INFO - ✓ Saved question: Will the European Court of Justice rule on the interpretation of Article 17 of t...
# 2025-11-30 14:49:09 - INFO -   Attempt 2/3
# 2025-11-30 14:49:15 - INFO - Search found 10 results for query: 'European Commission Supreme Court Decisions 2024...'
# 2025-11-30 14:49:17 - INFO -   Validating: Will the European Commission refer Poland to the European Co...
# 2025-11-30 14:49:20 - INFO - Search found 10 results for query: 'Will the European Commission refer Poland to the European Co...'
# 2025-11-30 14:49:22 - INFO - ✓ Saved question: Will the European Commission refer Poland to the European Court of Justice for n...
# 2025-11-30 14:49:22 - INFO -
# → Processing subcategory: National High Court Verdicts
# 2025-11-30 14:49:22 - INFO -
# → Processing subcategory: Constitutional Amendment Proposals
# 2025-11-30 14:49:22 - INFO -
# → Processing subcategory: Judicial Appointment Confirmations
# 2025-11-30 14:49:22 - INFO -
# ================================================================================
# 2025-11-30 14:49:22 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Legislative Actions
# 2025-11-30 14:49:22 - INFO - ================================================================================
# 2025-11-30 14:49:22 - INFO - Complexity: 8/10 | Budget: 5 questions
# 2025-11-30 14:49:22 - INFO - ================================================================================
#
# 2025-11-30 14:49:22 - INFO -
# → Processing subcategory: US Congressional Bill Passages
# 2025-11-30 14:49:22 - INFO -   Attempt 1/3
# 2025-11-30 14:49:28 - INFO - Search found 10 results for query: 'US Congress Legislative Actions 2025...'
# 2025-11-30 14:49:29 - INFO -   Validating: Will the US Congress pass the proposed Immigration Reform Bi...
# 2025-11-30 14:49:33 - INFO - Search found 10 results for query: 'Will the US Congress pass the proposed Immigration Reform Bi...'
# 2025-11-30 14:49:35 - INFO - ✓ Saved question: Will the US Congress pass the proposed Immigration Reform Bill before March 31, ...
# 2025-11-30 14:49:35 - INFO -   Attempt 2/3
# 2025-11-30 14:49:40 - INFO - Search found 10 results for query: 'US Senate Legislative Actions 2024...'
# 2025-11-30 14:49:42 - INFO -   Validating: Will the US Senate pass the proposed Climate Change Mitigati...
# 2025-11-30 14:49:45 - INFO - Search found 10 results for query: 'Will the US Senate pass the proposed Climate Change Mitigati...'
# 2025-11-30 14:49:49 - INFO - ✓ Saved question: Will the US Senate pass the proposed Climate Change Mitigation Act before Octobe...
# 2025-11-30 14:49:49 - INFO -   Attempt 3/3
# 2025-11-30 14:49:54 - INFO - Search found 10 results for query: 'US House of Representatives Legislative Actions 2024...'
# 2025-11-30 14:49:56 - INFO -   Validating: Will the US House of Representatives pass the proposed Cyber...
# 2025-11-30 14:49:59 - INFO - Search found 10 results for query: 'Will the US House of Representatives pass the proposed Cyber...'
# 2025-11-30 14:50:04 - INFO - ✗ Discarded question: Validation failed: The question does not provide clear information about the specific 'Cybersecurity Enhancement Act' being referred to, and the search results do not provide a clear answer to the question. The question does not contain any information that wasn't known on 2024-12-08. The question makes sense being asked on 2024-12-08, and the resolution date is after 2024-12-08.
# 2025-11-30 14:50:04 - INFO -
# → Processing subcategory: European Parliament Legislative Initiatives
# 2025-11-30 14:50:04 - INFO -   Attempt 1/3
# 2025-11-30 14:50:09 - INFO - Search found 10 results for query: 'European Parliament Legislative Actions 2025...'
# 2025-11-30 14:50:11 - INFO -   Validating: Will the European Parliament approve the proposed Artificial...
# 2025-11-30 14:50:13 - INFO - Search found 10 results for query: 'Will the European Parliament approve the proposed Artificial...'
# 2025-11-30 14:50:16 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:50:16 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:50:16 - INFO -   Attempt 2/3
# 2025-11-30 14:50:21 - INFO - Search found 10 results for query: 'European Commission Legislative Actions 2024...'
# 2025-11-30 14:50:23 - INFO -   Validating: Will the European Commission propose a new directive on cybe...
# 2025-11-30 14:50:26 - INFO - Search found 10 results for query: 'Will the European Commission propose a new directive on cybe...'
# 2025-11-30 14:50:28 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:50:28 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:50:28 - INFO -   Attempt 3/3
# 2025-11-30 14:50:33 - INFO - Search found 10 results for query: 'European Parliament Legislative Actions 2025...'
# 2025-11-30 14:50:35 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:50:35 - INFO -
# → Processing subcategory: National Lawmaking Processes
# 2025-11-30 14:50:35 - INFO -   Attempt 1/3
# 2025-11-30 14:50:41 - INFO - Search found 10 results for query: 'US Senate Legislative Actions 2025...'
# 2025-11-30 14:50:43 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:50:43 - INFO -   Attempt 2/3
# 2025-11-30 14:50:47 - INFO - Search found 10 results for query: 'United States Congress Legislative Actions 2025...'
# 2025-11-30 14:50:50 - INFO -   Validating: Will the United States Congress pass a comprehensive immigra...
# 2025-11-30 14:50:53 - INFO - Search found 10 results for query: 'Will the United States Congress pass a comprehensive immigra...'
# 2025-11-30 14:50:55 - INFO - ✓ Saved question: Will the United States Congress pass a comprehensive immigration reform bill bef...
# 2025-11-30 14:50:55 - INFO -   Attempt 3/3
# 2025-11-30 14:50:59 - INFO - Search found 10 results for query: 'European Union parliament Legislative Actions 2024...'
# 2025-11-30 14:51:01 - INFO -   Validating: Will the European Union parliament approve a uniform digital...
# 2025-11-30 14:51:04 - INFO - Search found 10 results for query: 'Will the European Union parliament approve a uniform digital...'
# 2025-11-30 14:51:07 - INFO - ✓ Saved question: Will the European Union parliament approve a uniform digital privacy law before ...
# 2025-11-30 14:51:07 - INFO -
# → Processing subcategory: State Legislative Session Outcomes
# 2025-11-30 14:51:07 - INFO -   Attempt 1/3
# 2025-11-30 14:51:12 - INFO - Search found 10 results for query: 'Texas State Legislature Legislative Actions 2025...'
# 2025-11-30 14:51:14 - INFO -   Validating: Will the Texas State Legislature pass a bill to increase ren...
# 2025-11-30 14:51:17 - INFO - Search found 10 results for query: 'Will the Texas State Legislature pass a bill to increase ren...'
# 2025-11-30 14:51:19 - INFO - ✓ Saved question: Will the Texas State Legislature pass a bill to increase renewable energy produc...
# 2025-11-30 14:51:19 - INFO -
# → Processing subcategory: Local Ordinance Approvals
# 2025-11-30 14:51:19 - INFO -
# ================================================================================
# 2025-11-30 14:51:19 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Public Protests
# 2025-11-30 14:51:19 - INFO - ================================================================================
# 2025-11-30 14:51:19 - INFO - Complexity: 6/10 | Budget: 4 questions
# 2025-11-30 14:51:19 - INFO - ================================================================================
#
# 2025-11-30 14:51:19 - INFO -
# → Processing subcategory: National Protest Movement Outcomes
# 2025-11-30 14:51:19 - INFO -   Attempt 1/3
# 2025-11-30 14:51:25 - INFO - Search found 10 results for query: 'Black Lives Matter movement Public Protests 2025...'
# 2025-11-30 14:51:28 - INFO -   Validating: Will the Black Lives Matter movement organize a national pro...
# 2025-11-30 14:51:30 - INFO - Search found 10 results for query: 'Will the Black Lives Matter movement organize a national pro...'
# 2025-11-30 14:51:33 - INFO - ✓ Saved question: Will the Black Lives Matter movement organize a national protest with over 100,0...
# 2025-11-30 14:51:33 - INFO -   Attempt 2/3
# 2025-11-30 14:51:39 - INFO - Search found 10 results for query: 'Climate Strike movement, led by Greta Thunberg Public Protes...'
# 2025-11-30 14:51:41 - INFO -   Validating: Will the Climate Strike movement, led by Greta Thunberg, sta...
# 2025-11-30 14:51:44 - INFO - Search found 10 results for query: 'Will the Climate Strike movement, led by Greta Thunberg, sta...'
# 2025-11-30 14:51:49 - INFO - ✗ Discarded question: Validation failed: The search results do not provide information about a specific protest on or before October 31, 2024, in at least 50 US cities. The question text does not contain information that wasn't known on 2024-10-24. The question makes sense being asked on 2024-10-24 and the resolution date is after 2024-10-24.
# 2025-11-30 14:51:49 - INFO -   Attempt 3/3
# 2025-11-30 14:51:54 - INFO - Search found 10 results for query: 'Women's March organization Public Protests 2024...'
# 2025-11-30 14:51:57 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:51:57 - INFO -
# → Processing subcategory: Global Demonstration Events
# 2025-11-30 14:51:57 - INFO -   Attempt 1/3
# 2025-11-30 14:52:02 - INFO - Search found 10 results for query: 'Extinction Rebellion Public Protests 2025...'
# 2025-11-30 14:52:04 - INFO -   Validating: Will the Extinction Rebellion movement organize a global cli...
# 2025-11-30 14:52:07 - INFO - Search found 10 results for query: 'Will the Extinction Rebellion movement organize a global cli...'
# 2025-11-30 14:52:09 - INFO - ✓ Saved question: Will the Extinction Rebellion movement organize a global climate protest before ...
# 2025-11-30 14:52:09 - INFO -   Attempt 2/3
# 2025-11-30 14:52:14 - INFO - Search found 10 results for query: 'Amnesty International Public Protests 2024...'
# 2025-11-30 14:52:16 - INFO -   Validating: Will the Amnesty International organization stage a mass dem...
# 2025-11-30 14:52:20 - INFO - Search found 10 results for query: 'Will the Amnesty International organization stage a mass dem...'
# 2025-11-30 14:52:22 - INFO - ✓ Saved question: Will the Amnesty International organization stage a mass demonstration in at lea...
# 2025-11-30 14:52:22 - INFO -   Attempt 3/3
# 2025-11-30 14:52:27 - INFO - Search found 10 results for query: 'Black Lives Matter movement Public Protests 2025...'
# 2025-11-30 14:52:29 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:52:29 - INFO -
# → Processing subcategory: Student-Led Protest Movements
# 2025-11-30 14:52:29 - INFO -   Attempt 1/3
# 2025-11-30 14:52:31 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:52:31 - INFO -   Attempt 2/3
# 2025-11-30 14:52:34 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:52:34 - INFO -   Attempt 3/3
# 2025-11-30 14:52:36 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:52:36 - INFO -
# → Processing subcategory: Labor Union Strike Actions
# 2025-11-30 14:52:36 - INFO -   Attempt 1/3
# 2025-11-30 14:52:38 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:52:38 - INFO -   Attempt 2/3
# 2025-11-30 14:52:41 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:52:41 - INFO -   Attempt 3/3
# 2025-11-30 14:52:43 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:52:43 - INFO -
# → Processing subcategory: Environmental Protest Campaigns
# 2025-11-30 14:52:43 - INFO -   Attempt 1/3
# 2025-11-30 14:52:45 - ERROR - Failed to parse question generation response: day is out of range for month
# 2025-11-30 14:52:45 - INFO -   Attempt 2/3
# 2025-11-30 14:52:51 - INFO - Search found 10 results for query: 'Extinction Rebellion Public Protests 2025...'
# 2025-11-30 14:52:53 - INFO -   Validating: Will Extinction Rebellion stage a major environmental protes...
# 2025-11-30 14:52:56 - INFO - Search found 10 results for query: 'Will Extinction Rebellion stage a major environmental protes...'
# 2025-11-30 14:53:01 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:53:01 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:53:01 - INFO -   Attempt 3/3
# 2025-11-30 14:53:06 - INFO - Search found 10 results for query: 'Greenpeace Public Protests 2024...'
# 2025-11-30 14:53:08 - INFO -   Validating: Will Greenpeace organize a nationwide campaign against singl...
# 2025-11-30 14:53:11 - INFO - Search found 10 results for query: 'Will Greenpeace organize a nationwide campaign against singl...'
# 2025-11-30 14:53:14 - INFO - ✓ Saved question: Will Greenpeace organize a nationwide campaign against single-use plastics in th...
# 2025-11-30 14:53:14 - INFO -
# ================================================================================
# 2025-11-30 14:53:14 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Economic Sanctions
# 2025-11-30 14:53:14 - INFO - ================================================================================
# 2025-11-30 14:53:14 - INFO - Complexity: 8/10 | Budget: 5 questions
# 2025-11-30 14:53:14 - INFO - ================================================================================
#
# 2025-11-30 14:53:14 - INFO -
# → Processing subcategory: US Economic Sanction Impositions
# 2025-11-30 14:53:14 - INFO -   Attempt 1/3
# 2025-11-30 14:53:19 - INFO - Search found 10 results for query: 'United States Economic Sanctions 2025...'
# 2025-11-30 14:53:21 - INFO -   Validating: Will the United States impose economic sanctions on China be...
# 2025-11-30 14:53:25 - INFO - Search found 10 results for query: 'Will the United States impose economic sanctions on China be...'
# 2025-11-30 14:53:27 - INFO - ✓ Saved question: Will the United States impose economic sanctions on China before March 31, 2025?...
# 2025-11-30 14:53:27 - INFO -   Attempt 2/3
# 2025-11-30 14:53:32 - INFO - Search found 10 results for query: 'Russia's energy sector Economic Sanctions 2024...'
# 2025-11-30 14:53:34 - INFO -   Validating: Will the United States impose economic sanctions on Russia's...
# 2025-11-30 14:53:37 - INFO - Search found 10 results for query: 'Will the United States impose economic sanctions on Russia's...'
# 2025-11-30 14:53:39 - INFO - ✓ Saved question: Will the United States impose economic sanctions on Russia's energy sector befor...
# 2025-11-30 14:53:39 - INFO -   Attempt 3/3
# 2025-11-30 14:53:45 - INFO - Search found 10 results for query: 'Venezuela's government Economic Sanctions 2024...'
# 2025-11-30 14:53:47 - WARNING - Question date 2024-04-11 00:00:00 is before simulated date
# 2025-11-30 14:53:47 - INFO -
# → Processing subcategory: European Union Trade Sanctions
# 2025-11-30 14:53:47 - INFO -   Attempt 1/3
# 2025-11-30 14:53:52 - INFO - Search found 10 results for query: 'European Union Economic Sanctions 2024...'
# 2025-11-30 14:53:54 - INFO -   Validating: Will the European Union impose trade sanctions on China befo...
# 2025-11-30 14:53:57 - INFO - Search found 10 results for query: 'Will the European Union impose trade sanctions on China befo...'
# 2025-11-30 14:53:59 - INFO - ✓ Saved question: Will the European Union impose trade sanctions on China before October 31, 2024?...
# 2025-11-30 14:53:59 - INFO -   Attempt 2/3
# 2025-11-30 14:54:05 - INFO - Search found 10 results for query: 'Russia Economic Sanctions 2025...'
# 2025-11-30 14:54:06 - INFO -   Validating: Will Russia face expanded European Union trade sanctions bef...
# 2025-11-30 14:54:09 - INFO - Search found 10 results for query: 'Will Russia face expanded European Union trade sanctions bef...'
# 2025-11-30 14:54:12 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:54:12 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:54:12 - INFO -   Attempt 3/3
# 2025-11-30 14:54:17 - INFO - Search found 10 results for query: 'Belarus Economic Sanctions 2025...'
# 2025-11-30 14:54:19 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:54:19 - INFO -
# → Processing subcategory: National Embargo Policies
# 2025-11-30 14:54:19 - INFO -   Attempt 1/3
# 2025-11-30 14:54:24 - INFO - Search found 10 results for query: 'The United States Economic Sanctions 2025...'
# 2025-11-30 14:54:26 - INFO -   Validating: Will the United States impose a national embargo on China be...
# 2025-11-30 14:54:29 - INFO - Search found 10 results for query: 'Will the United States impose a national embargo on China be...'
# 2025-11-30 14:54:32 - INFO - ✓ Saved question: Will the United States impose a national embargo on China before March 31, 2025?...
# 2025-11-30 14:54:32 - INFO -   Attempt 2/3
# 2025-11-30 14:54:36 - INFO - Search found 10 results for query: 'European Union Economic Sanctions 2024...'
# 2025-11-30 14:54:39 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:54:39 - INFO -   Attempt 3/3
# 2025-11-30 14:54:44 - INFO - Search found 10 results for query: 'European Union Economic Sanctions 2024...'
# 2025-11-30 14:54:46 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 14:54:46 - INFO -
# → Processing subcategory: International Trade Dispute Resolutions
# 2025-11-30 14:54:46 - INFO -   Attempt 1/3
# 2025-11-30 14:54:51 - INFO - Search found 10 results for query: 'The United States and China Economic Sanctions 2024...'
# 2025-11-30 14:54:53 - INFO -   Validating: Will the United States and China reach a trade agreement bef...
# 2025-11-30 14:54:56 - INFO - Search found 10 results for query: 'Will the United States and China reach a trade agreement bef...'
# 2025-11-30 14:54:58 - INFO - ✓ Saved question: Will the United States and China reach a trade agreement before October 31, 2024...
# 2025-11-30 14:54:58 - INFO -
# → Processing subcategory: Sanction Relief Measures
# 2025-11-30 14:54:58 - INFO -
# ================================================================================
# 2025-11-30 14:54:58 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Military Conflicts
# 2025-11-30 14:54:58 - INFO - ================================================================================
# 2025-11-30 14:54:58 - INFO - Complexity: 9/10 | Budget: 6 questions
# 2025-11-30 14:54:58 - INFO - ================================================================================
#
# 2025-11-30 14:54:58 - INFO -
# → Processing subcategory: US Military Intervention Decisions
# 2025-11-30 14:54:58 - INFO -   Attempt 1/3
# 2025-11-30 14:55:03 - INFO - Search found 10 results for query: 'US military Military Conflicts 2025...'
# 2025-11-30 14:55:05 - INFO -   Validating: Will the US military intervene in Ukraine before January 31,...
# 2025-11-30 14:55:08 - INFO - Search found 10 results for query: 'Will the US military intervene in Ukraine before January 31,...'
# 2025-11-30 14:55:12 - INFO - ✓ Saved question: Will the US military intervene in Ukraine before January 31, 2025?...
# 2025-11-30 14:55:12 - INFO -   Attempt 2/3
# 2025-11-30 14:55:17 - INFO - Search found 10 results for query: 'US military Military Conflicts 2024...'
# 2025-11-30 14:55:19 - INFO -   Validating: Will the US military deploy additional troops to Taiwan befo...
# 2025-11-30 14:55:22 - INFO - Search found 10 results for query: 'Will the US military deploy additional troops to Taiwan befo...'
# 2025-11-30 14:55:25 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 14:55:25 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 14:55:25 - INFO -   Attempt 3/3
# 2025-11-30 14:55:29 - INFO - Search found 10 results for query: 'US military Military Conflicts 2025...'
# ...
#
# 2025-11-30 15:10:41 - INFO -
# → Processing subcategory: US Space Agency Mission Launches
# 2025-11-30 15:10:41 - INFO -   Attempt 1/3
# 2025-11-30 15:10:47 - INFO - Search found 10 results for query: 'NASA Space Exploration 2024...'
# 2025-11-30 15:10:48 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 15:10:48 - INFO -   Attempt 2/3
# 2025-11-30 15:10:53 - INFO - Search found 10 results for query: 'NASA Space Exploration 2024...'
# 2025-11-30 15:10:55 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 15:10:55 - INFO -   Attempt 3/3
# 2025-11-30 15:11:00 - INFO - Search found 10 results for query: 'NASA Space Exploration 2024...'
# 2025-11-30 15:11:02 - INFO -   Validating: Will NASA launch the Artemis III mission before October 31, ...
# 2025-11-30 15:11:05 - INFO - Search found 10 results for query: 'Will NASA launch the Artemis III mission before October 31, ...'
# 2025-11-30 15:11:07 - INFO - ✓ Saved question: Will NASA launch the Artemis III mission before October 31, 2024?...
# 2025-11-30 15:11:07 - INFO -
# → Processing subcategory: European Space Agency Satellite Deployments
# 2025-11-30 15:11:07 - INFO -   Attempt 1/3
# 2025-11-30 15:11:13 - INFO - Search found 10 results for query: 'European Space Agency Space Exploration 2025...'
# 2025-11-30 15:11:14 - INFO -   Validating: Will the European Space Agency deploy the MTG-I2 satellite b...
# 2025-11-30 15:11:17 - INFO - Search found 10 results for query: 'Will the European Space Agency deploy the MTG-I2 satellite b...'
# 2025-11-30 15:11:20 - INFO - ✓ Saved question: Will the European Space Agency deploy the MTG-I2 satellite before March 31, 2025...
# 2025-11-30 15:11:20 - INFO -   Attempt 2/3
# 2025-11-30 15:11:25 - INFO - Search found 10 results for query: 'European Space Agency Space Exploration 2024...'
# 2025-11-30 15:11:26 - INFO -   Validating: Will the European Space Agency launch the JRSS-1 satellite b...
# 2025-11-30 15:11:29 - INFO - Search found 10 results for query: 'Will the European Space Agency launch the JRSS-1 satellite b...'
# 2025-11-30 15:11:31 - INFO - ✓ Saved question: Will the European Space Agency launch the JRSS-1 satellite before October 31, 20...
# 2025-11-30 15:11:31 - INFO -   Attempt 3/3
# 2025-11-30 15:11:36 - INFO - Search found 10 results for query: 'European Space Agency Space Exploration 2024...'
# 2025-11-30 15:11:38 - INFO -   Validating: Will the European Space Agency launch the Earth Explorer 10 ...
# 2025-11-30 15:11:41 - INFO - Search found 10 results for query: 'Will the European Space Agency launch the Earth Explorer 10 ...'
# 2025-11-30 15:11:43 - INFO - ✓ Saved question: Will the European Space Agency launch the Earth Explorer 10 mission before Decem...
# 2025-11-30 15:11:43 - INFO -
# → Processing subcategory: National Space Program Initiatives
# 2025-11-30 15:11:43 - INFO -
# → Processing subcategory: International Space Station Operations
# 2025-11-30 15:11:43 - INFO -
# → Processing subcategory: Private Space Company Launches
# 2025-11-30 15:11:43 - INFO -
# ================================================================================
# 2025-11-30 15:11:43 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Artificial Intelligence Regulations
# 2025-11-30 15:11:43 - INFO - ================================================================================
# 2025-11-30 15:11:43 - INFO - Complexity: 8/10 | Budget: 5 questions
# 2025-11-30 15:11:43 - INFO - ================================================================================
#
# 2025-11-30 15:11:43 - INFO -
# → Processing subcategory: US AI Development and Deployment Regulations
# 2025-11-30 15:11:43 - INFO -   Attempt 1/3
# 2025-11-30 15:11:49 - INFO - Search found 10 results for query: 'US Federal Trade Commission Artificial Intelligence Regulati...'
# 2025-11-30 15:11:51 - INFO -   Validating: Will the US Federal Trade Commission announce new regulation...
# 2025-11-30 15:11:54 - INFO - Search found 10 results for query: 'Will the US Federal Trade Commission announce new regulation...'
# 2025-11-30 15:11:57 - INFO - ✓ Saved question: Will the US Federal Trade Commission announce new regulations for artificial int...
# 2025-11-30 15:11:57 - INFO -   Attempt 2/3
# 2025-11-30 15:12:01 - INFO - Search found 10 results for query: 'Microsoft Artificial Intelligence Regulations 2024...'
# 2025-11-30 15:12:04 - INFO -   Validating: Will Microsoft implement AI-powered privacy features in its ...
# 2025-11-30 15:12:07 - INFO - Search found 10 results for query: 'Will Microsoft implement AI-powered privacy features in its ...'
# 2025-11-30 15:12:12 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 15:12:12 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 15:12:12 - INFO -   Attempt 3/3
# 2025-11-30 15:12:17 - INFO - Search found 10 results for query: 'Google Artificial Intelligence Regulations 2024...'
# 2025-11-30 15:12:19 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 15:12:19 - INFO -
# → Processing subcategory: European Union AI Ethics Guidelines
# 2025-11-30 15:12:19 - INFO -   Attempt 1/3
# 2025-11-30 15:12:24 - INFO - Search found 10 results for query: 'European Commission Artificial Intelligence Regulations 2025...'
# 2025-11-30 15:12:27 - INFO -   Validating: Will the European Commission announce updated AI Ethics Guid...
# 2025-11-30 15:12:30 - INFO - Search found 10 results for query: 'Will the European Commission announce updated AI Ethics Guid...'
# 2025-11-30 15:12:32 - INFO - ✓ Saved question: Will the European Commission announce updated AI Ethics Guidelines before March ...
# 2025-11-30 15:12:32 - INFO -   Attempt 2/3
# 2025-11-30 15:12:37 - INFO - Search found 10 results for query: 'Germany Artificial Intelligence Regulations 2024...'
# 2025-11-30 15:12:40 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 15:12:40 - INFO -   Attempt 3/3
# 2025-11-30 15:12:45 - INFO - Search found 10 results for query: 'German government Artificial Intelligence Regulations 2024...'
# 2025-11-30 15:12:47 - ERROR - Failed to parse answer search response: time data 'null' does not match format '%Y-%m-%d'
# 2025-11-30 15:12:47 - INFO -
# → Processing subcategory: National AI Research and Development Initiatives
# 2025-11-30 15:12:47 - INFO -   Attempt 1/3
# 2025-11-30 15:12:52 - INFO - Search found 10 results for query: 'European Union Artificial Intelligence Regulations 2025...'
# 2025-11-30 15:12:55 - ERROR - Failed to parse answer search response: time data '2024-05' does not match format '%Y-%m-%d'
# 2025-11-30 15:12:55 - INFO -   Attempt 2/3
# 2025-11-30 15:13:00 - INFO - Search found 10 results for query: 'European Union Artificial Intelligence Regulations 2025...'
# 2025-11-30 15:13:02 - INFO -   Validating: Will the European Union announce new regulations for artific...
# 2025-11-30 15:13:05 - INFO - Search found 10 results for query: 'Will the European Union announce new regulations for artific...'
# 2025-11-30 15:13:07 - INFO - ✓ Saved question: Will the European Union announce new regulations for artificial intelligence res...
# 2025-11-30 15:13:07 - INFO -   Attempt 3/3
# 2025-11-30 15:13:12 - INFO - Search found 10 results for query: 'National Science Foundation Artificial Intelligence Regulati...'
# 2025-11-30 15:13:14 - INFO -   Validating: Will the National Science Foundation allocate over $1 billio...
# 2025-11-30 15:13:17 - INFO - Search found 10 results for query: 'Will the National Science Foundation allocate over $1 billio...'
# 2025-11-30 15:13:20 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 15:13:20 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 15:13:20 - INFO -
# → Processing subcategory: International AI Cooperation Agreements
# 2025-11-30 15:13:20 - INFO -   Attempt 1/3
# 2025-11-30 15:13:25 - INFO - Search found 10 results for query: 'European Union and the United States Artificial Intelligence...'
# 2025-11-30 15:13:27 - INFO -   Validating: Will the European Union and the United States announce a joi...
# 2025-11-30 15:13:30 - INFO - Search found 10 results for query: 'Will the European Union and the United States announce a joi...'
# 2025-11-30 15:13:35 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 15:13:35 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 15:13:35 - INFO -   Attempt 2/3
# 2025-11-30 15:13:40 - INFO - Search found 10 results for query: 'Japan and Australia Artificial Intelligence Regulations 2024...'
# 2025-11-30 15:13:42 - INFO -   Validating: Will Japan and Australia establish a bilateral artificial in...
# 2025-11-30 15:13:45 - INFO - Search found 10 results for query: 'Will Japan and Australia establish a bilateral artificial in...'
# 2025-11-30 15:13:47 - WARNING - Answer mismatch - Historian: no, Critic: yes
# 2025-11-30 15:13:47 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 15:13:47 - INFO -   Attempt 3/3
# 2025-11-30 15:13:52 - INFO - Search found 10 results for query: 'China and India Artificial Intelligence Regulations 2024...'
# 2025-11-30 15:13:54 - INFO -   Validating: Will China and India sign a memorandum of understanding on a...
# 2025-11-30 15:13:57 - INFO - Search found 10 results for query: 'Will China and India sign a memorandum of understanding on a...'
# 2025-11-30 15:14:00 - INFO - ✓ Saved question: Will China and India sign a memorandum of understanding on artificial intelligen...
# 2025-11-30 15:14:00 - INFO -
# → Processing subcategory: AI-Related Legislation and Policy Frameworks
# 2025-11-30 15:14:00 - INFO -   Attempt 1/3
# 2025-11-30 15:14:05 - INFO - Search found 10 results for query: 'European Union Artificial Intelligence Regulations 2025...'
# 2025-11-30 15:14:07 - INFO -   Validating: Will the European Union announce AI regulations for business...
# 2025-11-30 15:14:10 - INFO - Search found 10 results for query: 'Will the European Union announce AI regulations for business...'
# 2025-11-30 15:14:13 - INFO - ✓ Saved question: Will the European Union announce AI regulations for businesses before March 31, ...
# 2025-11-30 15:14:13 - INFO -
# ================================================================================
# 2025-11-30 15:14:13 - INFO - [MODULE B & C: HISTORIAN + CRITIC] Category: Global Governance
# 2025-11-30 15:14:13 - INFO - ================================================================================
# 2025-11-30 15:14:13 - INFO - Complexity: 9/10 | Budget: 6 questions
# 2025-11-30 15:14:13 - INFO - ================================================================================
#
# 2025-11-30 15:14:13 - INFO -
# → Processing subcategory: United Nations Reform Initiatives
# 2025-11-30 15:14:13 - INFO -   Attempt 1/3
# 2025-11-30 15:14:18 - INFO - Search found 10 results for query: 'United Nations General Assembly Global Governance 2025...'
# 2025-11-30 15:14:20 - INFO -   Validating: Will the United Nations General Assembly approve a resolutio...
# 2025-11-30 15:14:23 - INFO - Search found 10 results for query: 'Will the United Nations General Assembly approve a resolutio...'
# 2025-11-30 15:14:25 - INFO - ✓ Saved question: Will the United Nations General Assembly approve a resolution on reforming the U...
# 2025-11-30 15:14:25 - INFO -   Attempt 2/3
# 2025-11-30 15:14:30 - INFO - Search found 10 results for query: 'European Union Global Governance 2024...'
# 2025-11-30 15:14:32 - INFO -   Validating: Will the European Union announce a new partnership with the ...
# 2025-11-30 15:14:35 - INFO - Search found 10 results for query: 'Will the European Union announce a new partnership with the ...'
# 2025-11-30 15:14:38 - INFO - ✓ Saved question: Will the European Union announce a new partnership with the United Nations to st...
# 2025-11-30 15:14:38 - INFO -   Attempt 3/3
# 2025-11-30 15:14:43 - INFO - Search found 10 results for query: 'African Union Global Governance 2025...'
# 2025-11-30 15:14:45 - INFO -   Validating: Will the African Union propose a comprehensive reform packag...
# 2025-11-30 15:14:48 - INFO - Search found 10 results for query: 'Will the African Union propose a comprehensive reform packag...'
# 2025-11-30 15:14:50 - INFO - ✓ Saved question: Will the African Union propose a comprehensive reform package for the United Nat...
# 2025-11-30 15:14:50 - INFO -
# → Processing subcategory: G20 Summit Outcomes
# 2025-11-30 15:14:50 - INFO -   Attempt 1/3
# 2025-11-30 15:14:55 - INFO - Search found 10 results for query: 'European Union Global Governance 2025...'
# 2025-11-30 15:14:57 - INFO -   Validating: Will the European Union announce a new trade agreement with ...
# 2025-11-30 15:15:00 - INFO - Search found 10 results for query: 'Will the European Union announce a new trade agreement with ...'
# 2025-11-30 15:15:02 - INFO - ✓ Saved question: Will the European Union announce a new trade agreement with India before March 3...
# 2025-11-30 15:15:02 - INFO -   Attempt 2/3
# 2025-11-30 15:15:04 - WARNING - Deadline 2025-11-15 is too recent (15 days ago). Need at least 30 days for information to be publicly available.
# 2025-11-30 15:15:04 - INFO -   Attempt 3/3
# 2025-11-30 15:15:09 - INFO - Search found 10 results for query: 'China Global Governance 2024...'
# 2025-11-30 15:15:12 - INFO -   Validating: Will China host a successful G20 Summit before November 15, ...
# 2025-11-30 15:15:14 - INFO - Search found 10 results for query: 'Will China host a successful G20 Summit before November 15, ...'
# 2025-11-30 15:15:17 - WARNING - Answer mismatch - Historian: yes, Critic: no
# 2025-11-30 15:15:17 - INFO - ✗ Discarded question: Answer mismatch between Historian and Critic
# 2025-11-30 15:15:17 - INFO -
# → Processing subcategory: International Monetary Fund Policy Decisions
# 2025-11-30 15:15:17 - INFO -   Attempt 1/3
# 2025-11-30 15:15:22 - INFO - Search found 10 results for query: 'International Monetary Fund Global Governance 2025...'
# 2025-11-30 15:15:24 - INFO -   Validating: Will the International Monetary Fund announce a new Special ...
# 2025-11-30 15:15:27 - INFO - Search found 10 results for query: 'Will the International Monetary Fund announce a new Special ...'
# 2025-11-30 15:15:29 - INFO - ✓ Saved question: Will the International Monetary Fund announce a new Special Drawing Rights alloc...
# 2025-11-30 15:15:29 - INFO -   Attempt 2/3
# 2025-11-30 15:15:34 - INFO - Search found 10 results for query: 'International Monetary Fund (IMF) and Argentina Global Gover...'
# 2025-11-30 15:15:37 - WARNING - Question date 2024-04-04 00:00:00 is before simulated date
# 2025-11-30 15:15:37 - INFO -   Attempt 3/3
# 2025-11-30 15:15:42 - INFO - Search found 10 results for query: 'The People's Bank of China Global Governance 2024...'
# 2025-11-30 15:15:45 - INFO -   Validating: Will the People's Bank of China increase its reserve require...
# 2025-11-30 15:15:48 - INFO - Search found 10 results for query: 'Will the People's Bank of China increase its reserve require...'
# 2025-11-30 15:15:50 - INFO - ✓ Saved question: Will the People's Bank of China increase its reserve requirements for commercial...
# 2025-11-30 15:15:50 - INFO -
# → Processing subcategory: World Trade Organization Agreement Negotiations
# 2025-11-30 15:15:50 - INFO -
# → Processing subcategory: Global Economic Governance Reforms
# 2025-11-30 15:15:50 - INFO -
# ================================================================================
# 2025-11-30 15:15:50 - INFO - PIPELINE EXECUTION COMPLETED
# 2025-11-30 15:15:50 - INFO - ================================================================================
# 2025-11-30 15:15:50 - INFO - Questions Attempted: 191
# 2025-11-30 15:15:50 - INFO - Questions Generated: 134
# 2025-11-30 15:15:50 - INFO - Questions Validated: 87
# 2025-11-30 15:15:50 - INFO - Questions Discarded: 47
# 2025-11-30 15:15:50 - INFO - Success Rate: 45.5%
# 2025-11-30 15:15:50 - INFO - ================================================================================

# %% [markdown]
# ## View Statistics
#
# Review the pipeline performance metrics.

# %%
print("\n" + "="*80)
print("PIPELINE STATISTICS")
print("="*80)
for key, value in stats.items():
    print(f"{key:30s}: {value}")
print("="*80)
# Out:
# ================================================================================
# PIPELINE STATISTICS
# ================================================================================
# total_attempted               : 191
# total_generated               : 134
# total_validated               : 87
# total_discarded               : 47
# categories_processed          : 19
# subcategories_processed       : 95
# subcategories_skipped         : 0
# ================================================================================

# %% [markdown]
# ## View Generated Questions
#
# Load and display the validated questions from the JSONL file.

# %%
import json
import os

# Load generated questions
questions = []
if os.path.exists(config['output_file']):
    with open(config['output_file'], 'r') as f:
        for line in f:
            questions.append(json.loads(line))

print("\n" + "="*80)
print(f"GENERATED QUESTIONS ({len(questions)} total)")
print("="*80)

for i, q in enumerate(questions, 1):
    print(f"\n{i}. {q['question']}")
    print(f"   Category: {q['category']} → {q['subcategory']}")
    print(f"   Question Date: {q['t_ask']}")
    print(f"   Resolution Date: {q['t_resolve']}")
    print(f"   Answer: {q['answer']}")
    print(f"   Complexity: {q['meta']['complexity_score']}/10")
    print(f"   Event: {q['meta']['event_description'][:100]}..." if q['meta']['event_description'] else "")

print("\n" + "="*80)
# Out:
# ================================================================================
# GENERATED QUESTIONS (87 total)
# ================================================================================
#
# 1. Will Joe Biden announce his candidacy for the 2024 US Presidential Election before December 31, 2024?
#    Category: Elections → US Presidential Election Results
#    Question Date: 2024-07-14
#    Resolution Date: 2024-07-21
#    Answer: No
#    Complexity: 9/10
#    Event: Joe Biden announced his withdrawal from the 2024 presidential election...
#
# 2. Will Gavin Newsom announce his candidacy for California Governor before October 31, 2024?
#    Category: Elections → State Governor Elections
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 9/10
#    Event: Gavin Newsom's term as governor ends and he is not running for re-election due to term limits...
#
# 3. Will Eric Adams win the New York City mayoral election before November 4, 2024?
#    Category: Elections → Local Mayoral Elections
#    Question Date: 2024-10-28
#    Resolution Date: 2024-11-04
#    Answer: No
#    Complexity: 9/10
#    Event: Eric Adams dropped out of the New York mayoral race...
#
# 4. Will the US Congress approve the federal budget for 2025 before October 1, 2024?
#    Category: Government Policies → US Federal Budget Approvals
#    Question Date: 2024-09-24
#    Resolution Date: 2024-10-01
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on the approval of the federal budget for 2025 before October 1, 2024...
#
# 5. Will the European Union and India finalize a free trade agreement before October 15, 2025?
#    Category: Government Policies → European Union Trade Agreements
#    Question Date: 2025-10-08
#    Resolution Date: 2025-10-15
#    Answer: No
#    Complexity: 8/10
#    Event: The European Union and India did not finalize a free trade agreement before October 15, 2025...
#
# 6. Will the European Parliament approve a comprehensive trade agreement with Australia before March 31, 2025?
#    Category: Government Policies → European Union Trade Agreements
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on the approval of a comprehensive trade agreement with Australia...
#
# 7. Will the Biden Administration announce a new national healthcare reform initiative before March 31, 2025?
#    Category: Government Policies → National Healthcare Reform Initiatives
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of a new national healthcare reform initiative announcement...
#
# 8. Will the state of California implement a single-payer healthcare system before October 1, 2025?
#    Category: Government Policies → National Healthcare Reform Initiatives
#    Question Date: 2025-09-24
#    Resolution Date: 2025-10-01
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of California implementing a single-payer healthcare system before October 1, 2025...
#
# 9. Will Turkey approve Sweden's NATO membership bid before October 31, 2024?
#    Category: International Relations → NATO Summit Outcomes
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 9/10
#    Event: No information found on Turkey approving Sweden's NATO membership bid...
#
# 10. Will the United States and NATO agree on a new defense spending plan before March 31, 2025?
#    Category: International Relations → NATO Summit Outcomes
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 9/10
#    Event: No clear evidence of a new defense spending plan agreement before the deadline...
#
# 11. Will the European Union and China announce a new trade agreement before October 31, 2024?
#    Category: International Relations → G20 Meeting Agreements
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 9/10
#    Event: No trade agreement announced between the European Union and China before the deadline...
#
# 12. Will India and the United States finalize a bilateral trade pact before March 31, 2025?
#    Category: International Relations → G20 Meeting Agreements
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 9/10
#    Event: India expects to secure a trade deal with the United States before the end of 2025, but no confirmat...
#
# 13. Will the United States and China announce a new trade deal before March 31, 2025?
#    Category: International Relations → US-China Trade Deal Negotiations
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 9/10
#    Event: No trade deal announcement found before the deadline...
#
# 14. Will Japan and China finalize a bilateral trade agreement before December 15, 2024?
#    Category: International Relations → US-China Trade Deal Negotiations
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of a finalized bilateral trade agreement between Japan and China...
#
# 15. Will the European Commission announce an investigation into corruption allegations against a high-ranking EU official before March 31, 2025?
#    Category: Political Scandals → European Union Corruption Cases
#    Question Date: 2025-03-06
#    Resolution Date: 2025-03-13
#    Answer: Yes
#    Complexity: 7/10
#    Event: European Commission faced a corruption scandal involving Huawei and the European Parliament, with ar...
#
# 16. Will the US Department of Justice announce charges against a high-ranking government official for national embezzlement before March 31, 2025?
#    Category: Political Scandals → National Embezzlement Scandals
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 7/10
#    Event: No charges announced against a high-ranking government official for national embezzlement before the...
#
# 17. Will the Nigerian government recover over $100 million in embezzled funds from former public officials before October 31, 2024?
#    Category: Political Scandals → National Embezzlement Scandals
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 7/10
#    Event: No information found on the recovery of over $100 million in embezzled funds...
#
# 18. Will the Brazilian Senate investigate and vote on impeachment of a cabinet member for alleged national embezzlement before December 15, 2024?
#    Category: Political Scandals → National Embezzlement Scandals
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 7/10
#    Event: No information found on the Brazilian Senate investigating and voting on impeachment of a cabinet me...
#
# 19. Will the US Supreme Court rule on the constitutionality of affirmative action in college admissions before March 31, 2025?
#    Category: Supreme Court Decisions → US Supreme Court Rulings
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on the US Supreme Court ruling on the constitutionality of affirmative action i...
#
# 20. Will the US Supreme Court issue a ruling on the environmental implications of the Clean Water Act before October 15, 2024?
#    Category: Supreme Court Decisions → US Supreme Court Rulings
#    Question Date: 2024-10-08
#    Resolution Date: 2024-10-15
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on a specific ruling related to the environmental implications of the Clean Wat...
#
# 21. Will Justice Ketanji Brown Jackson author a majority opinion in a significant case related to voting rights before December 31, 2024?
#    Category: Supreme Court Decisions → US Supreme Court Rulings
#    Question Date: 2024-12-24
#    Resolution Date: 2024-12-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of Justice Ketanji Brown Jackson authoring a majority opinion in a significant case rela...
#
# 22. Will the European Court of Justice rule on the interpretation of Article 17 of the Digital Services Act before March 31, 2025?
#    Category: Supreme Court Decisions → European Court of Justice Decisions
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on the European Court of Justice ruling on Article 17 of the Digital Services A...
#
# 23. Will the European Commission refer Poland to the European Court of Justice for non-compliance with EU law before October 31, 2024?
#    Category: Supreme Court Decisions → European Court of Justice Decisions
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of the European Commission referring Poland to the European Court of Justice for non-com...
#
# 24. Will the US Congress pass the proposed Immigration Reform Bill before March 31, 2025?
#    Category: Legislative Actions → US Congressional Bill Passages
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on the passage of the Immigration Reform Bill...
#
# 25. Will the US Senate pass the proposed Climate Change Mitigation Act before October 15, 2024?
#    Category: Legislative Actions → US Congressional Bill Passages
#    Question Date: 2024-10-08
#    Resolution Date: 2024-10-15
#    Answer: No
#    Complexity: 8/10
#    Event: Insufficient information to confirm passage of the Climate Change Mitigation Act...
#
# 26. Will the United States Congress pass a comprehensive immigration reform bill before March 31, 2025?
#    Category: Legislative Actions → National Lawmaking Processes
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No comprehensive immigration reform bill was mentioned as passed in the search results...
#
# 27. Will the European Union parliament approve a uniform digital privacy law before October 31, 2024?
#    Category: Legislative Actions → National Lawmaking Processes
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of the European Union parliament approving a uniform digital privacy law before October ...
#
# 28. Will the Texas State Legislature pass a bill to increase renewable energy production before March 1, 2025?
#    Category: Legislative Actions → State Legislative Session Outcomes
#    Question Date: 2025-02-22
#    Resolution Date: 2025-03-01
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of a bill to increase renewable energy production being passed...
#
# 29. Will the Black Lives Matter movement organize a national protest with over 100,000 attendees before March 31, 2025?
#    Category: Public Protests → National Protest Movement Outcomes
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 6/10
#    Event: No evidence of a national protest with over 100,000 attendees organized by the Black Lives Matter mo...
#
# 30. Will the Extinction Rebellion movement organize a global climate protest before March 31, 2025?
#    Category: Public Protests → Global Demonstration Events
#    Question Date: 2025-09-13
#    Resolution Date: 2025-09-20
#    Answer: Yes
#    Complexity: 6/10
#    Event: Extinction Rebellion organized multiple global climate protests...
#
# 31. Will the Amnesty International organization stage a mass demonstration in at least 10 countries against human rights violations before October 15, 2024?
#    Category: Public Protests → Global Demonstration Events
#    Question Date: 2024-10-08
#    Resolution Date: 2024-10-15
#    Answer: No
#    Complexity: 6/10
#    Event: No evidence of a mass demonstration in at least 10 countries against human rights violations by Amne...
#
# 32. Will Greenpeace organize a nationwide campaign against single-use plastics in the United States before October 31, 2024?
#    Category: Public Protests → Environmental Protest Campaigns
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 6/10
#    Event: No evidence of a nationwide campaign against single-use plastics in the United States before October...
#
# 33. Will the United States impose economic sanctions on China before March 31, 2025?
#    Category: Economic Sanctions → US Economic Sanction Impositions
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of economic sanctions imposed on China by the United States before March 31, 2025...
#
# 34. Will the United States impose economic sanctions on Russia's energy sector before October 31, 2024?
#    Category: Economic Sanctions → US Economic Sanction Impositions
#    Question Date: 2024-10-01
#    Resolution Date: 2024-10-08
#    Answer: Yes
#    Complexity: 8/10
#    Event: The United States imposed economic sanctions on Russia's energy sector...
#
# 35. Will the European Union impose trade sanctions on China before October 31, 2024?
#    Category: Economic Sanctions → European Union Trade Sanctions
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of EU imposing trade sanctions on China before October 31, 2024...
#
# 36. Will the United States impose a national embargo on China before March 31, 2025?
#    Category: Economic Sanctions → National Embargo Policies
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No national embargo on China was imposed by the United States before March 31, 2025...
#
# 37. Will the United States and China reach a trade agreement before October 31, 2024?
#    Category: Economic Sanctions → International Trade Dispute Resolutions
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 8/10
#    Event: No trade agreement mentioned in search results...
#
# 38. Will the US military intervene in Ukraine before January 31, 2025?
#    Category: Military Conflicts → US Military Intervention Decisions
#    Question Date: 2025-01-24
#    Resolution Date: 2025-01-31
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of US military intervention in Ukraine before January 31, 2025...
#
# 39. Will the United Nations deploy a peacekeeping mission to the Democratic Republic of Congo before March 31, 2025?
#    Category: Military Conflicts → International Peacekeeping Mission Deployments
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 9/10
#    Event: No information found on UN peacekeeping mission deployment to Democratic Republic of Congo...
#
# 40. Will the European Union deploy a peacekeeping force to Ukraine before October 31, 2024?
#    Category: Military Conflicts → International Peacekeeping Mission Deployments
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of EU deploying a peacekeeping force to Ukraine before October 31, 2024...
#
# 41. Will the African Union deploy a peacekeeping mission to the Sudan before January 15, 2025?
#    Category: Military Conflicts → International Peacekeeping Mission Deployments
#    Question Date: 2025-01-08
#    Resolution Date: 2025-01-15
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of African Union deploying a peacekeeping mission to Sudan before January 15, 2025...
#
# 42. Will the US Senate pass a comprehensive immigration reform bill before March 31, 2025?
#    Category: Immigration Policies → US Immigration Reform Initiatives
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No comprehensive immigration reform bill passed before March 31, 2025...
#
# 43. Will the U.S. Department of Homeland Security announce new national border control measures before March 31, 2025?
#    Category: Immigration Policies → National Border Control Measures
#    Question Date: 2025-02-17
#    Resolution Date: 2025-02-24
#    Answer: Yes
#    Complexity: 8/10
#    Event: The U.S. Department of Homeland Security announced new national border control measures...
#
# 44. Will the Canadian government implement enhanced biometric screening at all major border crossings before October 15, 2024?
#    Category: Immigration Policies → National Border Control Measures
#    Question Date: 2024-10-08
#    Resolution Date: 2024-10-15
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on enhanced biometric screening at major border crossings...
#
# 45. Will the United States government announce an increase in refugee admissions before January 31, 2025?
#    Category: Immigration Policies → Refugee Resettlement Programs
#    Question Date: 2025-01-24
#    Resolution Date: 2025-01-31
#    Answer: No
#    Complexity: 8/10
#    Event: No information found on the United States government announcing an increase in refugee admissions be...
#
# 46. Will the United States Citizenship and Immigration Services (USCIS) implement a new expedited asylum seeker processing procedure before March 31, 2025?
#    Category: Immigration Policies → Asylum Seeker Processing Procedures
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of a new expedited asylum seeker processing procedure implementation found...
#
# 47. Will the state of California implement stricter regulations on single-use plastics before December 15, 2024?
#    Category: Environmental Policies → US Environmental Protection Agency Regulations
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 7/10
#    Event: No evidence of stricter regulations on single-use plastics being implemented before December 15, 202...
#
# 48. Will the European Commission announce a new climate change initiative for the European Union before March 31, 2025?
#    Category: Environmental Policies → European Union Climate Change Initiatives
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 7/10
#    Event: No clear announcement of a new climate change initiative before the deadline...
#
# 49. Will Germany increase its renewable energy target to at least 70% of total energy production before October 31, 2024?
#    Category: Environmental Policies → European Union Climate Change Initiatives
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 7/10
#    Event: No clear evidence of Germany increasing its renewable energy target to at least 70% of total energy ...
#
# 50. Will the European Parliament approve a carbon pricing mechanism for the European Union's transportation sector before December 15, 2024?
#    Category: Environmental Policies → European Union Climate Change Initiatives
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 7/10
#    Event: No evidence of the European Parliament approving a carbon pricing mechanism for the EU's transportat...
#
# 51. Will the US Senate pass a revised healthcare reform bill before March 31, 2025?
#    Category: Healthcare Policies → US Healthcare Reform Legislation
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No clear evidence of a revised healthcare reform bill passing the US Senate before March 31, 2025...
#
# 52. Will the House of Representatives vote on a bill to lower prescription drug prices under Medicare before December 15, 2024?
#    Category: Healthcare Policies → US Healthcare Reform Legislation
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of the House of Representatives voting on a bill to lower prescription drug prices under...
#
# 53. Will the World Health Organization announce updated global pandemic response guidelines before March 31, 2025?
#    Category: Healthcare Policies → Global Pandemic Response Efforts
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No updated global pandemic response guidelines announced before March 31, 2025...
#
# 54. Will the National Alliance on Mental Illness (NAMI) launch a new mental health awareness campaign before March 31, 2025?
#    Category: Healthcare Policies → Mental Health Awareness Campaigns
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of a new mental health awareness campaign launch before March 31, 2025...
#
# 55. Will the American Psychological Association (APA) publish a comprehensive report on mental health in the workplace before June 30, 2025?
#    Category: Healthcare Policies → Mental Health Awareness Campaigns
#    Question Date: 2025-06-23
#    Resolution Date: 2025-06-30
#    Answer: No
#    Complexity: 8/10
#    Event: No comprehensive report on mental health in the workplace was found to be published by the APA befor...
#
# 56. Will the US Department of Education implement new student loan forgiveness policies before March 31, 2025?
#    Category: Education Policies → US Education Reform Initiatives
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 7/10
#    Event: No clear evidence of new student loan forgiveness policies being implemented before March 31, 2025...
#
# 57. Will the state of California pass legislation to make community college free for all residents before October 31, 2024?
#    Category: Education Policies → US Education Reform Initiatives
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 7/10
#    Event: No legislation making community college free for all California residents was found in the search re...
#
# 58. Will the city of New York announce a universal pre-kindergarten expansion plan before December 15, 2024?
#    Category: Education Policies → US Education Reform Initiatives
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 7/10
#    Event: No information found on universal pre-kindergarten expansion plan announcement...
#
# 59. Will the European Commission propose a new framework for recognizing foreign academic qualifications before March 31, 2025?
#    Category: Education Policies → European Union Education Policy Frameworks
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 7/10
#    Event: No evidence of a new framework proposal before the deadline...
#
# 60. Will the California High-Speed Rail Authority break ground on the Los Angeles to San Diego segment before October 31, 2024?
#    Category: Infrastructure Development → US Transportation Infrastructure Projects
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 7/10
#    Event: No evidence of groundbreaking on the Los Angeles to San Diego segment before the deadline...
#
# 61. Will the Italian energy company, Enel, announce plans to invest in a new solar farm project in Eastern Europe before October 31, 2024?
#    Category: Infrastructure Development → European Union Energy Infrastructure Initiatives
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 7/10
#    Event: No announcement of a new solar farm project in Eastern Europe found...
#
# 62. Will the Federal Communications Commission (FCC) announce the completion of the national broadband expansion project before October 31, 2024?
#    Category: Infrastructure Development → National Broadband Expansion Efforts
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 7/10
#    Event: No announcement of completion found...
#
# 63. Will Google Fiber achieve broadband coverage of at least 80% of rural areas in the United States before March 31, 2025?
#    Category: Infrastructure Development → National Broadband Expansion Efforts
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 7/10
#    Event: No evidence of achieving 80% broadband coverage in rural areas...
#
# 64. Will the US Senate pass a comprehensive cybersecurity legislation bill before March 31, 2025?
#    Category: Cybersecurity Measures → US Cybersecurity Legislation
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No comprehensive cybersecurity legislation bill was found to have been passed by the US Senate befor...
#
# 65. Will the US House of Representatives introduce a bipartisan cybersecurity information sharing bill before October 31, 2024?
#    Category: Cybersecurity Measures → US Cybersecurity Legislation
#    Question Date: 2024-12-10
#    Resolution Date: 2024-12-17
#    Answer: Yes
#    Complexity: 8/10
#    Event: The US House of Representatives introduced a bipartisan cybersecurity information sharing bill...
#
# 66. Will the US Department of Homeland Security announce new cybersecurity standards for critical infrastructure before December 15, 2024?
#    Category: Cybersecurity Measures → US Cybersecurity Legislation
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 8/10
#    Event: No announcement of new cybersecurity standards found...
#
# 67. Will the European Commission implement new cybersecurity measures for the General Data Protection Regulation before March 31, 2025?
#    Category: Cybersecurity Measures → European Union Data Protection Regulations
#    Question Date: 2025-11-12
#    Resolution Date: 2025-11-19
#    Answer: No
#    Complexity: 8/10
#    Event: The European Commission proposed new measures, but there's no clear evidence they were implemented b...
#
# 68. Will the United States government launch a new national cybersecurity awareness campaign before October 31, 2024?
#    Category: Cybersecurity Measures → National Cybersecurity Awareness Campaigns
#    Question Date: 2024-09-12
#    Resolution Date: 2024-09-19
#    Answer: Yes
#    Complexity: 8/10
#    Event: The United States government announced new cybersecurity measures for 2024...
#
# 69. Will the American Red Cross provide disaster relief services to over 50,000 people affected by hurricanes in the southern United States before October 31, 2024?
#    Category: Disaster Response → US Natural Disaster Relief Efforts
#    Question Date: 2024-10-08
#    Resolution Date: 2024-10-15
#    Answer: Yes
#    Complexity: 7/10
#    Event: The American Red Cross provided disaster relief services to people affected by hurricanes in the sou...
#
# 70. Will the European Commission activate the EU Civil Protection Mechanism in response to a natural disaster before October 31, 2024?
#    Category: Disaster Response → European Union Emergency Response Mechanisms
#    Question Date: 2024-09-12
#    Resolution Date: 2024-09-19
#    Answer: Yes
#    Complexity: 7/10
#    Event: The European Commission activated the EU Civil Protection Mechanism in response to natural disasters...
#
# 71. Will the United States Army Corps of Engineers announce new national flood control measures before March 31, 2025?
#    Category: Disaster Response → National Flood Control Measures
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 7/10
#    Event: No announcement of new national flood control measures found...
#
# 72. Will the United States Forest Service announce a new wildfire prevention initiative before March 31, 2025?
#    Category: Disaster Response → Wildfire Management and Prevention Initiatives
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 7/10
#    Event: No evidence of a new wildfire prevention initiative announcement before March 31, 2025...
#
# 73. Will NASA launch the Artemis III mission before October 31, 2024?
#    Category: Space Exploration → US Space Agency Mission Launches
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 6/10
#    Event: No information found on the launch of Artemis III before October 31, 2024...
#
# 74. Will the European Space Agency deploy the MTG-I2 satellite before March 31, 2025?
#    Category: Space Exploration → European Space Agency Satellite Deployments
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 6/10
#    Event: No information found about the deployment of the MTG-I2 satellite...
#
# 75. Will the European Space Agency launch the JRSS-1 satellite before October 31, 2024?
#    Category: Space Exploration → European Space Agency Satellite Deployments
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 6/10
#    Event: No information about JRSS-1 satellite launch found...
#
# 76. Will the European Space Agency launch the Earth Explorer 10 mission before December 15, 2024?
#    Category: Space Exploration → European Space Agency Satellite Deployments
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 6/10
#    Event: No information about the Earth Explorer 10 mission launch found...
#
# 77. Will the US Federal Trade Commission announce new regulations for artificial intelligence development before March 31, 2025?
#    Category: Artificial Intelligence Regulations → US AI Development and Deployment Regulations
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of new regulations announcement by the US Federal Trade Commission before March 31, 2025...
#
# 78. Will the European Commission announce updated AI Ethics Guidelines before March 31, 2025?
#    Category: Artificial Intelligence Regulations → European Union AI Ethics Guidelines
#    Question Date: 2025-01-28
#    Resolution Date: 2025-02-04
#    Answer: Yes
#    Complexity: 8/10
#    Event: The European Commission published Guidelines on prohibited artificial intelligence practices...
#
# 79. Will the European Union announce new regulations for artificial intelligence research and development before March 31, 2025?
#    Category: Artificial Intelligence Regulations → National AI Research and Development Initiatives
#    Question Date: 2024-07-25
#    Resolution Date: 2024-08-01
#    Answer: Yes
#    Complexity: 8/10
#    Event: The European Union announced new regulations for artificial intelligence research and development th...
#
# 80. Will China and India sign a memorandum of understanding on artificial intelligence standards before December 15, 2024?
#    Category: Artificial Intelligence Regulations → International AI Cooperation Agreements
#    Question Date: 2024-12-08
#    Resolution Date: 2024-12-15
#    Answer: No
#    Complexity: 8/10
#    Event: No evidence of a memorandum of understanding on artificial intelligence standards between China and ...
#
# 81. Will the European Union announce AI regulations for businesses before March 31, 2025?
#    Category: Artificial Intelligence Regulations → AI-Related Legislation and Policy Frameworks
#    Question Date: 2024-07-25
#    Resolution Date: 2024-08-01
#    Answer: Yes
#    Complexity: 8/10
#    Event: The European Union announced AI regulations for businesses through the EU AI Act...
#
# 82. Will the United Nations General Assembly approve a resolution on reforming the UN Security Council before March 31, 2025?
#    Category: Global Governance → United Nations Reform Initiatives
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of UN Security Council reform resolution approval found...
#
# 83. Will the European Union announce a new partnership with the United Nations to strengthen global governance before October 31, 2024?
#    Category: Global Governance → United Nations Reform Initiatives
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 9/10
#    Event: No announcement of a new partnership with the United Nations was found in the search results...
#
# 84. Will the African Union propose a comprehensive reform package for the United Nations Development Programme before August 15, 2025?
#    Category: Global Governance → United Nations Reform Initiatives
#    Question Date: 2025-08-08
#    Resolution Date: 2025-08-15
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of the African Union proposing a comprehensive reform package for the United Nations Dev...
#
# 85. Will the European Union announce a new trade agreement with India before March 31, 2025?
#    Category: Global Governance → G20 Summit Outcomes
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of a new trade agreement announcement found...
#
# 86. Will the International Monetary Fund announce a new Special Drawing Rights allocation before March 31, 2025?
#    Category: Global Governance → International Monetary Fund Policy Decisions
#    Question Date: 2025-03-24
#    Resolution Date: 2025-03-31
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of a new Special Drawing Rights allocation announcement before March 31, 2025...
#
# 87. Will the People's Bank of China increase its reserve requirements for commercial banks to counter inflation before October 31, 2024?
#    Category: Global Governance → International Monetary Fund Policy Decisions
#    Question Date: 2024-10-24
#    Resolution Date: 2024-10-31
#    Answer: No
#    Complexity: 9/10
#    Event: No evidence of the People's Bank of China increasing reserve requirements for commercial banks to co...
#
# ================================================================================

# %% [markdown]
# ## View Discarded Questions
#
# Review questions that failed validation (useful for debugging and understanding failure modes).

# %%
# Load discarded questions
discarded = []
if os.path.exists(config['discarded_file']):
    with open(config['discarded_file'], 'r') as f:
        for line in f:
            discarded.append(json.loads(line))

print("\n" + "="*80)
print(f"DISCARDED QUESTIONS ({len(discarded)} total)")
print("="*80)

for i, d in enumerate(discarded[:5], 1):  # Show first 5
    print(f"\n{i}. {d['question_data']['question']}")
    print(f"   Reason: {d['reason']}")
    print(f"   Historian Answer: {d['question_data'].get('answer', 'N/A')}")
    print(f"   Critic Answer: {d['validation_data'].get('answer', 'N/A')}")

if len(discarded) > 5:
    print(f"\n... and {len(discarded) - 5} more discarded questions")

print("\n" + "="*80)
# Out:
# ================================================================================
# DISCARDED QUESTIONS (47 total)
# ================================================================================
#
# 1. Will the European People's Party win the most seats in the European Parliament before June 1, 2025?
#    Reason: Answer mismatch between Historian and Critic
#    Historian Answer: No
#    Critic Answer: Yes
#
# 2. Will Joe Biden announce his candidacy for the 2024 United States presidential election before October 31, 2024?
#    Reason: Answer mismatch between Historian and Critic
#    Historian Answer: No
#    Critic Answer: Yes
#
# 3. Will the Biden Administration announce a new federal budget proposal for 2026 before March 15, 2025?
#    Reason: Answer mismatch between Historian and Critic
#    Historian Answer: Yes
#    Critic Answer: No
#
# 4. Will the European Commission announce a new trade agreement with the United Kingdom before December 31, 2024?
#    Reason: Answer mismatch between Historian and Critic
#    Historian Answer: No
#    Critic Answer: Yes
#
# 5. Will NATO announce an expansion to include North Macedonia and Finland before January 31, 2025?
#    Reason: Answer mismatch between Historian and Critic
#    Historian Answer: No
#    Critic Answer: Yes
#
# ... and 42 more discarded questions
#
# ================================================================================

# %% [markdown]
# ## Example: Data Schema
#
# Here's what a single question looks like in the JSONL file:

# %%
if questions:
    print("\nExample Question Record:")
    print("="*80)
    print(json.dumps(questions[0], indent=2))
    print("="*80)
# Out:
# Example Question Record:
# ================================================================================
# {
#   "id": "cc06d066-3231-48ed-930a-218dff5057d9",
#   "topic": "Politics",
#   "category": "Elections",
#   "subcategory": "US Presidential Election Results",
#   "question": "Will Joe Biden announce his candidacy for the 2024 US Presidential Election before December 31, 2024?",
#   "t_ask": "2024-07-14",
#   "t_resolve": "2024-07-21",
#   "answer": "No",
#   "meta": {
#     "complexity_score": 9,
#     "validation_confidence": "High",
#     "event_description": "Joe Biden announced his withdrawal from the 2024 presidential election"
#   }
# }
# ================================================================================

# %% [markdown]
# ## Understanding the Data Schema
#
# Each question in `generated_questions.jsonl` has this structure:
#
# ```json
# {
#   "id": "uuid_v4_string",           // Unique identifier
#   "topic": "Technology",            // Main topic
#   "category": "AI",                 // Category from taxonomy
#   "subcategory": "LLM Releases",    // Specific subcategory
#   "question": "Will...",            // Binary Yes/No question
#   "t_ask": "2024-03-15",            // Question date (simulated past)
#   "t_resolve": "2024-03-22",        // Resolution date (actual event)
#   "answer": "Yes",                  // Ground truth answer
#   "meta": {
#     "complexity_score": 8,          // Topic complexity (1-10)
#     "validation_confidence": "High", // Critic's confidence
#     "event_description": "..."      // What happened
#   }
# }
# ```
#
# ### Key Properties:
#
# - **No News Context Saved**: Only the answer is saved (prevents model bias)
# - **Time Safety**: `t_ask = t_resolve - 7 days` (configurable buffer)
# - **Append-Only**: JSONL format allows safe concurrent writes
# - **Crash-Proof**: Each write is flushed with `os.fsync()`

# %% [markdown]
# ## Resuming from Checkpoint
#
# If the pipeline crashes or is interrupted, it will automatically resume from where it left off.
#
# The `completed_log.txt` file tracks processed subcategories:
#
# ```
# Technology|Artificial Intelligence|LLM Releases
# Technology|Artificial Intelligence|AI Startups
# Technology|Cybersecurity|Data Breaches
# ...
# ```
#
# Simply re-run the pipeline with the same configuration, and it will skip completed subcategories.

# %%
# View checkpoint file
if os.path.exists(config['checkpoint_file']):
    with open(config['checkpoint_file'], 'r') as f:
        completed = f.readlines()
    
    print("\n" + "="*80)
    print(f"COMPLETED SUBCATEGORIES ({len(completed)} total)")
    print("="*80)
    for line in completed[:10]:  # Show first 10
        print(f"  ✓ {line.strip()}")
    
    if len(completed) > 10:
        print(f"  ... and {len(completed) - 10} more")
    print("="*80)
else:
    print("No checkpoint file found.")
# Out:
# ================================================================================
# COMPLETED SUBCATEGORIES (95 total)
# ================================================================================
#   ✓ Politics|Elections|US Presidential Election Results
#   ✓ Politics|Elections|European Parliamentary Election Outcomes
#   ✓ Politics|Elections|National Leadership Elections
#   ✓ Politics|Elections|State Governor Elections
#   ✓ Politics|Elections|Local Mayoral Elections
#   ✓ Politics|Government Policies|US Federal Budget Approvals
#   ✓ Politics|Government Policies|European Union Trade Agreements
#   ✓ Politics|Government Policies|National Healthcare Reform Initiatives
#   ✓ Politics|Government Policies|Environmental Protection Legislation
#   ✓ Politics|Government Policies|Tax Reform Bills
#   ... and 85 more
# ================================================================================
